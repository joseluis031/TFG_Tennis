# %% [markdown]
# CODIGO PARA FORMATEAR LAS COLUMNA DE FECHA Y
# POSTERIORMENTE VAMOS A HACER LIMPIEZA DE ESAS VARIABLES Y DIVIDIR EN GENERALES Y EN PISTA:
# EN EL ULTIMO AÑO (2024+2025)
# DESDE 2020 A 2023
# PARA VER SU MEJORIA Y TENERLO EN CUENTA EN EL INFORME

# %%
import os
import pandas as pd
import numpy as np
import re

# %%
# Carpetas
input_folder = 'Tests/calidad_de_resto'
output_folder = 'Tests/calidad_de_resto_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_resto.csv procesado correctamente.
# AndreyRublev_resto.csv procesado correctamente.
# CarlosAlcaraz_resto.csv procesado correctamente.
# CasperRuud_resto.csv procesado correctamente.
# DaniilMedvedev_resto.csv procesado correctamente.
# HolgerRune_resto.csv procesado correctamente.
# HubertHurkacz_resto.csv procesado correctamente.
# JannikSinner_resto.csv procesado correctamente.
# NovakDjokovic_resto.csv procesado correctamente.
# StefanosTsitsipas_resto.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/calidad_de_resto_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_resto.csv
# Match        0
# RiP%         0
# RiP W%       0
# RetWnr%      0
# FH/BH        0
# RDI          0
# Slice%       0
# 1st: RiP%    0
# RiP W%.1     0
# RetWnr%.1    0
# RDI.1        0
# Slice%.1     0
# 2nd: RiP%    0
# RiP W%.2     0
# RetWnr%.2    0
# RDI.2        0
# Slice%.2     0
# W_or_L       0
# Rival        0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_resto.csv
# Match        0
# RiP%         0
# RiP W%       0
# RetWnr%      0
# FH/BH        0
# RDI          0
# Slice%       0
# 1st: RiP%    0
# RiP W%.1     0
# RetWnr%.1    0
# RDI.1        0
# Slice%.1     0
# 2nd: RiP%    0
# RiP W%.2     0
# RetWnr%.2    0
# RDI.2        0
# Slice%.2     0
# W_or_L       0
# Rival        0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_resto.csv
# Match        0
# RiP%         0
# RiP W%       0
# RetWnr%      0
# FH/BH        0
# RDI          0
# Slice%       0
# 1st: RiP%    0
# RiP W%.1     0
# RetWnr%.1    0
# ...

# %%
# Carpetas
input_folder = 'Tests/calidad_rally'
output_folder = 'Tests/calidad_rally_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_rally.csv procesado correctamente.
# AndreyRublev_rally.csv procesado correctamente.
# CarlosAlcaraz_rally.csv procesado correctamente.
# CasperRuud_rally.csv procesado correctamente.
# DaniilMedvedev_rally.csv procesado correctamente.
# HolgerRune_rally.csv procesado correctamente.
# HubertHurkacz_rally.csv procesado correctamente.
# JannikSinner_rally.csv procesado correctamente.
# NovakDjokovic_rally.csv procesado correctamente.
# StefanosTsitsipas_rally.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/calidad_rally_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_rally.csv
# Match          0
# RallyLen       0
# RLen-Serve     0
# RLen-Return    0
# 1-3 W%         0
# 4-6 W%         0
# 7-9 W%         0
# 10+ W%         0
# FH/GS          0
# BH Slice%      0
# FHP            0
# FHP/100        0
# BHP            0
# BHP/100        0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_rally.csv
# Match          0
# RallyLen       0
# RLen-Serve     0
# RLen-Return    0
# 1-3 W%         0
# 4-6 W%         0
# 7-9 W%         0
# 10+ W%         0
# FH/GS          0
# BH Slice%      0
# FHP            0
# FHP/100        0
# BHP            0
# BHP/100        0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_rally.csv
# Match          0
# RallyLen       0
# RLen-Serve     0
# RLen-Return    0
# 1-3 W%         0
# 4-6 W%         0
# 7-9 W%         0
# 10+ W%         0
# FH/GS          0
# BH Slice%      0
# FHP            0
# ...

# %%
# Carpetas
input_folder = 'Tests/calidad_servicio'
output_folder = 'Tests/calidad_servicio_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_servicio.csv procesado correctamente.
# AndreyRublev_servicio.csv procesado correctamente.
# CarlosAlcaraz_servicio.csv procesado correctamente.
# CasperRuud_servicio.csv procesado correctamente.
# DaniilMedvedev_servicio.csv procesado correctamente.
# HolgerRune_servicio.csv procesado correctamente.
# HubertHurkacz_servicio.csv procesado correctamente.
# JannikSinner_servicio.csv procesado correctamente.
# NovakDjokovic_servicio.csv procesado correctamente.
# StefanosTsitsipas_servicio.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/calidad_servicio_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_servicio.csv
# Match          0
# Unret%         0
# <=3 W%         0
# RiP W%         0
# SvImpact       0
# 1st: Unret%    0
# <=3 W%.1       0
# RiP W%.1       0
# SvImpact.1     0
# D Wide%        0
# A Wide%        0
# BP Wide%       0
# 2nd: Unret%    0
# <=3 W%.2       0
# RiP W%.2       0
# 2ndAgg         0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_servicio.csv
# Match          0
# Unret%         0
# <=3 W%         0
# RiP W%         0
# SvImpact       0
# 1st: Unret%    0
# <=3 W%.1       0
# RiP W%.1       0
# SvImpact.1     0
# D Wide%        0
# A Wide%        0
# BP Wide%       0
# 2nd: Unret%    0
# <=3 W%.2       0
# RiP W%.2       0
# 2ndAgg         0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_servicio.csv
# Match          0
# Unret%         0
# <=3 W%         0
# RiP W%         0
# SvImpact       0
# 1st: Unret%    0
# ...

# %%
# Carpetas
input_folder = 'Tests/calidad_tactics'
output_folder = 'Tests/calidad_tactics_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_tactics.csv procesado correctamente.
# AndreyRublev_tactics.csv procesado correctamente.
# CarlosAlcaraz_tactics.csv procesado correctamente.
# CasperRuud_tactics.csv procesado correctamente.
# DaniilMedvedev_tactics.csv procesado correctamente.
# HolgerRune_tactics.csv procesado correctamente.
# HubertHurkacz_tactics.csv procesado correctamente.
# JannikSinner_tactics.csv procesado correctamente.
# NovakDjokovic_tactics.csv procesado correctamente.
# StefanosTsitsipas_tactics.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/calidad_tactics_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_tactics.csv
# Match         0
# SnV Freq      0
# SnV W%        0
# Net Freq      0
# Net W%        0
# FH: Wnr%      0
# DTL Wnr%      0
# IO Wnr%       0
# BH: Wnr%      0
# DTL Wnr%.1    0
# Drop: Freq    0
# Wnr%          0
# RallyAgg      0
# ReturnAgg     0
# W_or_L        0
# Rival         0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_tactics.csv
# Match         0
# SnV Freq      0
# SnV W%        0
# Net Freq      0
# Net W%        0
# FH: Wnr%      0
# DTL Wnr%      0
# IO Wnr%       0
# BH: Wnr%      0
# DTL Wnr%.1    0
# Drop: Freq    0
# Wnr%          0
# RallyAgg      0
# ReturnAgg     0
# W_or_L        0
# Rival         0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_tactics.csv
# Match         0
# SnV Freq      0
# SnV W%        0
# Net Freq      0
# Net W%        0
# FH: Wnr%      0
# DTL Wnr%      0
# IO Wnr%       0
# BH: Wnr%      0
# DTL Wnr%.1    0
# Drop: Freq    0
# Wnr%          0
# RallyAgg      0
# ...

# %%
# Carpetas
input_folder = 'Tests/key_games_results'
output_folder = 'Tests/key_games_results_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_key_games.csv procesado correctamente.
# AndreyRublev_key_games.csv procesado correctamente.
# CarlosAlcaraz_key_games.csv procesado correctamente.
# CasperRuud_key_games.csv procesado correctamente.
# DaniilMedvedev_key_games.csv procesado correctamente.
# HolgerRune_key_games.csv procesado correctamente.
# HubertHurkacz_key_games.csv procesado correctamente.
# JannikSinner_key_games.csv procesado correctamente.
# NovakDjokovic_key_games.csv procesado correctamente.
# StefanosTsitsipas_key_games.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/key_games_results_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_key_games.csv
# Match          0
# BP Games       0
# BP Conv/BPG    0
# BreakBack%     0
# BPF Games      0
# Hold/BPFG      0
# Consol%        0
# SvForSet       0
# SvStaySet      0
# SvForMatch     0
# SvStayMatch    0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_key_games.csv
# Match          0
# BP Games       0
# BP Conv/BPG    0
# BreakBack%     0
# BPF Games      0
# Hold/BPFG      0
# Consol%        0
# SvForSet       0
# SvStaySet      0
# SvForMatch     0
# SvStayMatch    0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_key_games.csv
# Match          0
# BP Games       0
# BP Conv/BPG    0
# BreakBack%     0
# BPF Games      0
# Hold/BPFG      0
# Consol%        0
# SvForSet       0
# SvStaySet      0
# SvForMatch     0
# SvStayMatch    0
# W_or_L         0
# Rival          0
# dtype: int64
#
# Nulos por columna en: CasperRuud_key_games.csv
# ...

# %%
# Carpetas
input_folder = 'Tests/key_points_results'
output_folder = 'Tests/key_points_results_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_key_points.csv procesado correctamente.
# AndreyRublev_key_points.csv procesado correctamente.
# CarlosAlcaraz_key_points.csv procesado correctamente.
# CasperRuud_key_points.csv procesado correctamente.
# DaniilMedvedev_key_points.csv procesado correctamente.
# HolgerRune_key_points.csv procesado correctamente.
# HubertHurkacz_key_points.csv procesado correctamente.
# JannikSinner_key_points.csv procesado correctamente.
# NovakDjokovic_key_points.csv procesado correctamente.
# StefanosTsitsipas_key_points.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/key_points_results_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_key_points.csv
# Match       0
# GP Conv     0
# BP Conv     0
# SP Conv     0
# MP Conv     0
# BP Saved    0
# SP Saved    0
# MP Saved    0
# TB SPW      0
# TB RPW      0
# W_or_L      0
# Rival       0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_key_points.csv
# Match       0
# GP Conv     0
# BP Conv     0
# SP Conv     0
# MP Conv     0
# BP Saved    0
# SP Saved    0
# MP Saved    0
# TB SPW      0
# TB RPW      0
# W_or_L      0
# Rival       0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_key_points.csv
# Match       0
# GP Conv     0
# BP Conv     0
# SP Conv     0
# MP Conv     0
# BP Saved    0
# SP Saved    0
# MP Saved    0
# TB SPW      0
# TB RPW      0
# W_or_L      0
# Rival       0
# dtype: int64
#
# Nulos por columna en: CasperRuud_key_points.csv
# Match       0
# GP Conv     0
# BP Conv     0
# SP Conv     0
# MP Conv     0
# BP Saved    0
# SP Saved    0
# MP Saved    0
# TB SPW      0
# TB RPW      0
# ...

# %%
# Carpetas
input_folder = 'Tests/point_by_point_stats_results'
output_folder = 'Tests/point_by_point_stats_results_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_pbp_stats.csv procesado correctamente.
# AndreyRublev_pbp_stats.csv procesado correctamente.
# CarlosAlcaraz_pbp_stats.csv procesado correctamente.
# CasperRuud_pbp_stats.csv procesado correctamente.
# DaniilMedvedev_pbp_stats.csv procesado correctamente.
# HolgerRune_pbp_stats.csv procesado correctamente.
# HubertHurkacz_pbp_stats.csv procesado correctamente.
# JannikSinner_pbp_stats.csv procesado correctamente.
# NovakDjokovic_pbp_stats.csv procesado correctamente.
# StefanosTsitsipas_pbp_stats.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/point_by_point_stats_results_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_pbp_stats.csv
# Match         0
# BLR           0
# DR+           0
# EI            0
# CBF           0
# Deuce A%      0
# Deuce SPW%    0
# Ad A%         0
# Ad SPW%       0
# Deuce RPW%    0
# Ad RPW%       0
# W_or_L        0
# Rival         0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_pbp_stats.csv
# Match         0
# BLR           0
# DR+           0
# EI            0
# CBF           0
# Deuce A%      0
# Deuce SPW%    0
# Ad A%         0
# Ad SPW%       0
# Deuce RPW%    0
# Ad RPW%       0
# W_or_L        0
# Rival         0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_pbp_stats.csv
# Match         0
# BLR           0
# DR+           0
# EI            0
# CBF           0
# Deuce A%      0
# Deuce SPW%    0
# Ad A%         0
# Ad SPW%       0
# Deuce RPW%    0
# Ad RPW%       0
# W_or_L        0
# Rival         0
# dtype: int64
#
# Nulos por columna en: CasperRuud_pbp_stats.csv
# Match         0
# BLR           0
# ...

# %%
# Carpetas
input_folder = 'Tests/winners_errors_results'
output_folder = 'Tests/winners_errors_results_limpio'
os.makedirs(output_folder, exist_ok=True)

# Procesar cada CSV en la carpeta
for filename in os.listdir(input_folder):
    if filename.endswith('.csv'):
        input_path = os.path.join(input_folder, filename)
        df = pd.read_csv(input_path)

        if 'Result' not in df.columns:
            print(f"{filename}: no se encontró columna 'Result', se omite.")
            continue

        # Limpiar columna Result y dividirla
        df['Result'] = df['Result'].astype(str).str.strip()
        df['W_or_L'] = df['Result'].str[0]
        df['Rival'] = df['Result'].str.extract(r'vs(.+)', expand=False).str.strip()

        # Eliminar columna original
        df = df.drop(columns=['Result'])

        # Guardar nuevo CSV
        output_path = os.path.join(output_folder, filename)
        df.to_csv(output_path, index=False)
        print(f"{filename} procesado correctamente.")
# Out:
# AlexanderZverev_winners_errors.csv procesado correctamente.
# AndreyRublev_winners_errors.csv procesado correctamente.
# CarlosAlcaraz_winners_errors.csv procesado correctamente.
# CasperRuud_winners_errors.csv procesado correctamente.
# DaniilMedvedev_winners_errors.csv procesado correctamente.
# HolgerRune_winners_errors.csv procesado correctamente.
# HubertHurkacz_winners_errors.csv procesado correctamente.
# JannikSinner_winners_errors.csv procesado correctamente.
# NovakDjokovic_winners_errors.csv procesado correctamente.
# StefanosTsitsipas_winners_errors.csv procesado correctamente.

# %%
# Carpeta con los CSVs
folder = 'Tests/winners_errors_results_limpio'

# Revisar cada archivo
for filename in os.listdir(folder):
    if filename.endswith('.csv'):
        path = os.path.join(folder, filename)
        df = pd.read_csv(path)

        print(f"\nNulos por columna en: {filename}")
        print(df.isnull().sum())
# Out:
# Nulos por columna en: AlexanderZverev_winners_errors.csv
# Match            0
# Winners          0
# UFEs             0
# Ratio            0
# Wnr/Pt           0
# UFE/Pt           0
# RallyWinners     0
# RallyUFEs        0
# RallyRatio       0
# Rally Wnr/Pt     0
# Rally UFE/Pt     0
# FH Wnr/Pt       34
# BH Wnr/Pt       34
# vs Ratio         0
# vs Wnr/Pt        0
# vs UFE/Pt        0
# W_or_L           0
# Rival            0
# dtype: int64
#
# Nulos por columna en: AndreyRublev_winners_errors.csv
# Match            0
# Winners          0
# UFEs             0
# Ratio            0
# Wnr/Pt           0
# UFE/Pt           0
# RallyWinners     0
# RallyUFEs        0
# RallyRatio       0
# Rally Wnr/Pt     0
# Rally UFE/Pt     0
# FH Wnr/Pt       18
# BH Wnr/Pt       18
# vs Ratio         0
# vs Wnr/Pt        0
# vs UFE/Pt        0
# W_or_L           0
# Rival            0
# dtype: int64
#
# Nulos por columna en: CarlosAlcaraz_winners_errors.csv
# Match           0
# ...

# %% [markdown]
# EL RIVAL NO LO VAMOS A TENER EN CUENTA ASI QUE, LA CARPETA TEST_LIMPIO HAY QUE ELIMINARLA

# %%
import os
import pandas as pd

# Configuración
carpeta_entrada = 'Tests_limpio/calidad_de_resto_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/calidad_de_resto3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/calidad_rally_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/calidad_rally3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/calidad_servicio_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/calidad_servicio3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/calidad_tactics_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/calidad_tactics3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/key_games_results_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/key_games_results3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/key_points_results_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/key_points_results3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/point_by_point_stats_results_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/point_by_point_stats_results3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Configuración
carpeta_entrada = 'Tests_limpio/winners_errors_results_limpio'         # Carpeta con CSVs originales
carpeta_salida = 'Test_3/winners_errors_results3'     # Carpeta para guardar los nuevos CSVs

# Crear carpeta de salida si no existe
os.makedirs(carpeta_salida, exist_ok=True)

# Función para dividir la columna "Match"
def dividir_match(valor):
    partes = valor.strip().split()
    if len(partes) < 3:
        return pd.Series([None, None, None])  # Maneja casos incorrectos
    date = partes[0]
    rd = partes[-1]
    tournament = ' '.join(partes[1:-1])
    return pd.Series([date, tournament, rd])

# Procesar cada archivo CSV
for archivo in os.listdir(carpeta_entrada):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_entrada, archivo)
        df = pd.read_csv(ruta_csv)

        # Aplicar la división de la columna "Match"
        df[['Date', 'Tournament', 'Rd']] = df['Match'].apply(dividir_match)

        # Eliminar la columna original "Match"
        df = df.drop(columns=['Match'])

        # (Opcional) Mover las nuevas columnas al principio
        columnas_ordenadas = ['Date', 'Tournament', 'Rd'] + [col for col in df.columns if col not in ['Date', 'Tournament', 'Rd']]
        df = df[columnas_ordenadas]

        # Guardar el CSV modificado
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Conversión completada.")
# Out:
# Conversión completada.

# %%
# Procesar todos los archivos CSV
for archivo in os.listdir(carpeta_salida):
    if archivo.endswith('.csv'):
        ruta_csv = os.path.join(carpeta_salida, archivo)
        df = pd.read_csv(ruta_csv)



        # Reordenar columnas: mover la última a la posición 4
        cols = df.columns.tolist()
        last_col = cols[-1]
        cols.remove(last_col)
        cols.insert(3, last_col)  # Insertar en la posición 4 (5ta columna)
        df = df[cols]

        # Guardar
        ruta_salida = os.path.join(carpeta_salida, archivo)
        df.to_csv(ruta_salida, index=False)

print("Columnas reorganizadas. Archivos guardados en:", carpeta_salida)
# Out:
# Columnas reorganizadas. Archivos guardados en: Test_3/winners_errors_results3

# %%
# Ruta de la carpeta
carpeta = "Test_3/point_by_point_stats_results3"
csv_files = [f for f in os.listdir(carpeta) if f.endswith(".csv")]

# Analizar nulos y guiones por archivo
for file in csv_files:
    path = os.path.join(carpeta, file)
    df = pd.read_csv(path)
    
    print(f"\nArchivo: {file}")
    print("Nulos por columna:")
    print(df.isna().sum())
    print("\nGuiones '-' por columna:")
    print((df == '-').sum())
# Out:
# Archivo: AlexanderZverev_pbp_stats.csv
# Nulos por columna:
# Date          0
# Tournament    0
# Rd            0
# Rival         0
# BLR           0
# DR+           0
# EI            0
# CBF           0
# Deuce A%      0
# Deuce SPW%    0
# Ad A%         0
# Ad SPW%       0
# Deuce RPW%    0
# Ad RPW%       0
# W_or_L        0
# dtype: int64
#
# Guiones '-' por columna:
# Date           0
# Tournament     0
# Rd             0
# Rival          0
# BLR            0
# DR+            0
# EI             0
# CBF            0
# Deuce A%      13
# Deuce SPW%     0
# Ad A%         13
# Ad SPW%        0
# Deuce RPW%     0
# Ad RPW%        0
# W_or_L         0
# dtype: int64
#
# Archivo: AndreyRublev_pbp_stats.csv
# Nulos por columna:
# Date          0
# Tournament    0
# Rd            0
# Rival         0
# BLR           0
# DR+           0
# EI            0
# CBF           0
# Deuce A%      0
# Deuce SPW%    0
# Ad A%         0
# Ad SPW%       0
# Deuce RPW%    0
# Ad RPW%       0
# ...

# %% [markdown]
# AQUI EMPIEZO LA LIMPIEZA

# %%
# listas de torneo en superficie hard
torneos_hard = [
    "Australian Open",
    "Miami",
    "Indian Wells",
    "US Open",
    "Cincinnati",
    "Paris",
    "Doha",
    "Brisbane",
    "Tour Finals",
    "Dubai",
    "Adelaide 1",
    "Shanghai",
    "Tokyo",
    "Montreal",
    "Canada",
    "Rotterdam",
    "Beijing",
    "Acapulco"
    "Auckland",
    "Delray Beach",
    "Indian Wells Masters",
    "Miami Masters",
    "Cincinnati Masters",
    "Shanghai Masters",
    "Paris Masters",
    "Canada Masters",
]
# listas de torneo en superficie clay
torneos_clay = [
    "Roland Garros",
    "Monte Carlo",
    "Barcelona Open",
    "Madrid",
    "Rome",
    "Geneva",
    "Barcelona",
    "Buenos Aires",
    "Santiago",
    "Hamburg",
    "Munich",
    "Rio de Janeiro",
    "Houston",
    "Nice",
    "Stuttgart",
    "Madrid Masters",
    "Rome Masters",
    "Monte Carlo Masters",
]

# %% [markdown]
# ver que hago aqui para poder explicarlo

# %%
# Carpetas
carpeta_entrada = "Test_3/winners_errors_results3"
carpeta_salida = "Test_3/winners_errors_results"
os.makedirs(carpeta_salida, exist_ok=True)

# csv_files = [f for f in os.listdir(carpeta_entrada) if f.endswith(".csv")]

# for file in csv_files:
#     path = os.path.join(carpeta_entrada, file)
#     df = pd.read_csv(path)

#     for col in df.columns:
#         # Verifica si hay '-'
#         if (df[col] == '-').any():
#             # Reemplaza '-' por NaN y convierte a numérico
#             df[col] = pd.to_numeric(df[col].replace('-', pd.NA), errors='coerce')
#             # Calcula la media y redondea a 1 decimal
#             media = round(df[col].mean(skipna=True), 1)
#             # Rellena los NaN con la media
#             df[col] = df[col].fillna(media)
#         #verifica si esta vacio y rellan con la media de esa columna
        
        
#             # #eliminar columna BP Wide%
#             # if col == 'Deuce A%':
#             #     df = df.drop(columns=['Deuce A%'])
#             # elif col == 'Ad A%':
#             #     df = df.drop(columns=['Ad A%'])

#     # Guarda el archivo limpio
#     df.to_csv(os.path.join(carpeta_salida, file), index=False)
#     print(f"Procesado y guardado: {file}")

for file in csv_files:
    path = os.path.join(carpeta_entrada, file)

    # Leer el CSV, tratando vacíos correctamente
    df = pd.read_csv(path, na_values=["", " ", "-", "NaN"], keep_default_na=True)

    # Eliminar filas que contengan al menos un valor nulo
    df_clean = df.dropna(axis=0, how='any')

    # Guardar archivo limpio
    df_clean.to_csv(os.path.join(carpeta_salida, file), index=False)
    print(f"Filas con nulos eliminadas en: {file}")
# Out:
# Filas con nulos eliminadas en: AlexanderZverev_winners_errors.csv
# Filas con nulos eliminadas en: AndreyRublev_winners_errors.csv
# Filas con nulos eliminadas en: CarlosAlcaraz_winners_errors.csv
# Filas con nulos eliminadas en: CasperRuud_winners_errors.csv
# Filas con nulos eliminadas en: DaniilMedvedev_winners_errors.csv
# Filas con nulos eliminadas en: HolgerRune_winners_errors.csv
# Filas con nulos eliminadas en: HubertHurkacz_winners_errors.csv
# Filas con nulos eliminadas en: JannikSinner_winners_errors.csv
# Filas con nulos eliminadas en: NovakDjokovic_winners_errors.csv
# Filas con nulos eliminadas en: StefanosTsitsipas_winners_errors.csv

# %% [markdown]
# Puede que haya eliminado, columnas que haya visto que tienen nulos

# %% [markdown]
# DURA 2019

# %%
# Carpeta de entrada y salida
subcarpeta = "calidad_de_resto"
# subcarpeta = "calidad_rally3"
# subcarpeta = "calidad_servicio"
# subcarpeta = "calidad_tactics"
# subcarpeta = "point_by_point_stats_results"
# subcarpeta = "winners_errors_results3"

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
# ruta_salida = os.path.join(base_dir, "Juego_2024_25")
ruta_salida = os.path.join(base_dir, "Juego_2019_23")
ruta_salida_hard = os.path.join(ruta_salida, "hard")
# ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)



# Columnas que no deben incluirse en la media
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_resto.csv", "").replace(".csv", "")
    # jugador = file.replace("_rally.csv", "").replace(".csv", "")
    # jugador = file.replace("_servicio.csv", "").replace(".csv", "")
    # jugador = file.replace("_tactics.csv", "").replace(".csv", "")
    # jugador = file.replace("_winners_errors.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)
    df = pd.read_csv(path)

    # Filtrar por fechas 2024 o 2025
    # df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    df = df[df['Tournament'].isin(torneos_hard)]
    # df = df[df['Tournament'].isin(torneos_clay)]

    if df.empty:
        print(f"⚠ Sin datos hard para {jugador}, se omite.")
        continue


    # Reemplazar % por número sin dividir entre 100
    df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)

    # Eliminar columnas excluidas si están
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir columnas a numéricas donde se pueda
    df_numeric = df.apply(pd.to_numeric, errors='coerce')

    # Calcular medias redondeadas
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir el nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# Unir todo en un DataFrame
df_resumen = pd.DataFrame(resumen)

# Guardar CSV resumen
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
# salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 10
#       3 # subcarpeta = "calidad_rally3"
#       4 # subcarpeta = "calidad_servicio"
#       5 # subcarpeta = "calidad_tactics"
#       6 # subcarpeta = "point_by_point_stats_results"
#       7 # subcarpeta = "winners_errors_results3"
#       9 base_dir = "Test_3"
# ---> 10 ruta_entrada = os.path.join(base_dir, subcarpeta)
#      11 # ruta_salida = os.path.join(base_dir, "Juego_2024_25")
#      12 ruta_salida = os.path.join(base_dir, "Juego_2019_23")
#
# NameError: name 'os' is not defined

# %% [markdown]
# DURA 2024

# %%
# Carpeta de entrada y salida
# subcarpeta = "calidad_de_resto"
# subcarpeta = "calidad_rally3"
# subcarpeta = "calidad_servicio"
# subcarpeta = "calidad_tactics"
# subcarpeta = "point_by_point_stats_results"
subcarpeta = "winners_errors_results3"

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
ruta_salida = os.path.join(base_dir, "Juego_2024_25")
# ruta_salida = os.path.join(base_dir, "Juego_2019_23")
ruta_salida_hard = os.path.join(ruta_salida, "hard")
# ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)



# Columnas que no deben incluirse en la media
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    # jugador = file.replace("_resto.csv", "").replace(".csv", "")
    # jugador = file.replace("_rally.csv", "").replace(".csv", "")
    # jugador = file.replace("_servicio.csv", "").replace(".csv", "")
    # jugador = file.replace("_tactics.csv", "").replace(".csv", "")
    jugador = file.replace("_winners_errors.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)
    df = pd.read_csv(path)

    # Filtrar por fechas 2024 o 2025
    df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    # df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    df = df[df['Tournament'].isin(torneos_hard)]
    # df = df[df['Tournament'].isin(torneos_clay)]

    if df.empty:
        print(f"⚠ Sin datos hard para {jugador}, se omite.")
        continue


    # Reemplazar % por número sin dividir entre 100
    df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)

    # Eliminar columnas excluidas si están
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir columnas a numéricas donde se pueda
    df_numeric = df.apply(pd.to_numeric, errors='coerce')

    # Calcular medias redondeadas
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir el nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# Unir todo en un DataFrame
df_resumen = pd.DataFrame(resumen)

# Guardar CSV resumen
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
# salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\887390153.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\887390153.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\887390153.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\887390153.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %% [markdown]
# TIERRA 2019

# %%
# Carpeta de entrada y salida
subcarpeta = "calidad_de_resto"
# subcarpeta = "calidad_rally3"
# subcarpeta = "calidad_servicio"
# subcarpeta = "calidad_tactics"
# subcarpeta = "point_by_point_stats_results"
# subcarpeta = "winners_errors_results3"

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
# ruta_salida = os.path.join(base_dir, "Juego_2024_25")
ruta_salida = os.path.join(base_dir, "Juego_2019_23")
# ruta_salida_hard = os.path.join(ruta_salida, "hard")
ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)



# Columnas que no deben incluirse en la media
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_resto.csv", "").replace(".csv", "")
    # jugador = file.replace("_rally.csv", "").replace(".csv", "")
    # jugador = file.replace("_servicio.csv", "").replace(".csv", "")
    # jugador = file.replace("_tactics.csv", "").replace(".csv", "")
    # jugador = file.replace("_winners_errors.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)
    df = pd.read_csv(path)

    # Filtrar por fechas 2024 o 2025
    # df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    # df = df[df['Tournament'].isin(torneos_hard)]
    df = df[df['Tournament'].isin(torneos_clay)]

    if df.empty:
        print(f"⚠ Sin datos hard para {jugador}, se omite.")
        continue


    # Reemplazar % por número sin dividir entre 100
    df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)

    # Eliminar columnas excluidas si están
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir columnas a numéricas donde se pueda
    df_numeric = df.apply(pd.to_numeric, errors='coerce')

    # Calcular medias redondeadas
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir el nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# Unir todo en un DataFrame
df_resumen = pd.DataFrame(resumen)

# Guardar CSV resumen
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
# salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# Resumen guardado en: Test_3\Juego_2019_23\clay\calidad_de_resto_clay.csv
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1274888917.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1274888917.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1274888917.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# ...

# %% [markdown]
# TIERRA 2024

# %%
# Carpeta de entrada y salida
subcarpeta = "calidad_de_resto"
# subcarpeta = "calidad_rally3"
# subcarpeta = "calidad_servicio"
# subcarpeta = "calidad_tactics"
# subcarpeta = "point_by_point_stats_results"
# subcarpeta = "winners_errors_results3"

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
ruta_salida = os.path.join(base_dir, "Juego_2024_25")
# ruta_salida = os.path.join(base_dir, "Juego_2019_23")
# ruta_salida_hard = os.path.join(ruta_salida, "hard")
ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)



# Columnas que no deben incluirse en la media
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_resto.csv", "").replace(".csv", "")
    # jugador = file.replace("_rally.csv", "").replace(".csv", "")
    # jugador = file.replace("_servicio.csv", "").replace(".csv", "")
    # jugador = file.replace("_tactics.csv", "").replace(".csv", "")
    # jugador = file.replace("_winners_errors.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)
    df = pd.read_csv(path)

    # Filtrar por fechas 2024 o 2025
    df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    # df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    # df = df[df['Tournament'].isin(torneos_hard)]
    df = df[df['Tournament'].isin(torneos_clay)]

    if df.empty:
        print(f"⚠ Sin datos hard para {jugador}, se omite.")
        continue


    # Reemplazar % por número sin dividir entre 100
    df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)

    # Eliminar columnas excluidas si están
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir columnas a numéricas donde se pueda
    df_numeric = df.apply(pd.to_numeric, errors='coerce')

    # Calcular medias redondeadas
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir el nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# Unir todo en un DataFrame
df_resumen = pd.DataFrame(resumen)

# Guardar CSV resumen
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
# salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# Resumen guardado en: Test_3\Juego_2024_25\clay\calidad_de_resto_clay.csv
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1146661711.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1146661711.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\1146661711.py:53: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x: float(str(x).replace('%', '')) if isinstance(x, str) and '%' in x else x)
# ...

# %% [markdown]
# DURA 2019

# %%
# === CONFIGURACIÓN ===
subcarpeta = "key_games_results3"
# subcarpeta = "key_points_results3"  
# subcarpeta = "point_by_point_stats_results3"  

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
# ruta_salida = os.path.join(base_dir, "Juego_2024_25")
ruta_salida = os.path.join(base_dir, "Juego_2019_23")
ruta_salida_hard = os.path.join(ruta_salida, "hard")
# ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)

# Columnas que no deben incluirse en el cálculo de medias
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

# === FUNCIÓN DE LIMPIEZA DE CELDAS ===
def limpiar_celda(valor):
    if pd.isna(valor):
        return None
    valor = str(valor).strip()

    # Caso: "35% (6/17)" → 35.0
    if '%' in valor and '(' in valor:
        match = re.search(r'(\d+(?:\.\d+)?)%', valor)
        return float(match.group(1)) if match else None

    # Caso especial: "0/0" → NaN
    if valor == "0/0":
        return np.nan
    
    elif valor == "-":
        return np.nan

    # Caso: "6/17" → porcentaje
    if '/' in valor:
        try:
            num, den = map(float, valor.split('/'))
            return round((num / den) * 100, 2) if den != 0 else np.nan
        except:
            return np.nan

    # Caso: "83%" → 83.0
    if valor.endswith('%'):
        try:
            return float(valor.strip('%'))
        except:
            return np.nan

    # Intentar convertir a número directo
    try:
        return float(valor)
    except:
        return np.nan

# === PROCESAMIENTO ===
resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_key_games.csv", "").replace(".csv", "")
    # jugador = file.replace("_pbp_stats.csv", "").replace(".csv", "")
    # jugador = file.replace("_key_points.csv", "").replace(".csv", "")
    path = os.path.join(ruta_entrada, file)

    df = pd.read_csv(path)

    # Filtrar por años 2024 o 2025
    # df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    df = df[df['Tournament'].isin(torneos_hard)]
    # df = df[df['Tournament'].isin(torneos_clay)]

    # Limpiar todas las celdas según reglas definidas
    df = df.applymap(limpiar_celda)

    # Eliminar columnas excluidas
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir a numérico y calcular medias
    df_numeric = df.apply(pd.to_numeric, errors='coerce')
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# === GUARDAR RESULTADO ===
df_resumen = pd.DataFrame(resumen)
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
# salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\95741073.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\95741073.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\95741073.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\95741073.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\95741073.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# ...

# %% [markdown]
# DURA 2024

# %%
# === CONFIGURACIÓN ===
# subcarpeta = "key_games_results3"
# subcarpeta = "key_points_results3"  
subcarpeta = "point_by_point_stats_results3"  

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
ruta_salida = os.path.join(base_dir, "Juego_2024_25")
# ruta_salida = os.path.join(base_dir, "Juego_2019_23")
ruta_salida_hard = os.path.join(ruta_salida, "hard")
# ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)

# Columnas que no deben incluirse en el cálculo de medias
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

# === FUNCIÓN DE LIMPIEZA DE CELDAS ===
def limpiar_celda(valor):
    if pd.isna(valor):
        return None
    valor = str(valor).strip()

    # Caso: "35% (6/17)" → 35.0
    if '%' in valor and '(' in valor:
        match = re.search(r'(\d+(?:\.\d+)?)%', valor)
        return float(match.group(1)) if match else None

    # Caso especial: "0/0" → NaN
    if valor == "0/0":
        return np.nan
    
    elif valor == "-":
        return np.nan

    # Caso: "6/17" → porcentaje
    if '/' in valor:
        try:
            num, den = map(float, valor.split('/'))
            return round((num / den) * 100, 2) if den != 0 else np.nan
        except:
            return np.nan

    # Caso: "83%" → 83.0
    if valor.endswith('%'):
        try:
            return float(valor.strip('%'))
        except:
            return np.nan

    # Intentar convertir a número directo
    try:
        return float(valor)
    except:
        return np.nan

# === PROCESAMIENTO ===
resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    # jugador = file.replace("_key_games.csv", "").replace(".csv", "")
    jugador = file.replace("_pbp_stats.csv", "").replace(".csv", "")
    # jugador = file.replace("_key_points.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)

    df = pd.read_csv(path)

    # Filtrar por años 2024 o 2025
    df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    # df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    df = df[df['Tournament'].isin(torneos_hard)]
    # df = df[df['Tournament'].isin(torneos_clay)]

    # Limpiar todas las celdas según reglas definidas
    df = df.applymap(limpiar_celda)

    # Eliminar columnas excluidas
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir a numérico y calcular medias
    df_numeric = df.apply(pd.to_numeric, errors='coerce')
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# === GUARDAR RESULTADO ===
df_resumen = pd.DataFrame(resumen)
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
# salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\2403472243.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\2403472243.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\2403472243.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\2403472243.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_22052\2403472243.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# ...

# %% [markdown]
# TIERRA 2019

# %%
# === CONFIGURACIÓN ===
subcarpeta = "key_games_results3"
# subcarpeta = "key_points_results3"  
# subcarpeta = "point_by_point_stats_results3"  

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
# ruta_salida = os.path.join(base_dir, "Juego_2024_25")
ruta_salida = os.path.join(base_dir, "Juego_2019_23")
# ruta_salida_hard = os.path.join(ruta_salida, "hard")
ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)

# Columnas que no deben incluirse en el cálculo de medias
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

# === FUNCIÓN DE LIMPIEZA DE CELDAS ===
def limpiar_celda(valor):
    if pd.isna(valor):
        return None
    valor = str(valor).strip()

    # Caso: "35% (6/17)" → 35.0
    if '%' in valor and '(' in valor:
        match = re.search(r'(\d+(?:\.\d+)?)%', valor)
        return float(match.group(1)) if match else None

    # Caso especial: "0/0" → NaN
    if valor == "0/0":
        return np.nan
    
    elif valor == "-":
        return np.nan

    # Caso: "6/17" → porcentaje
    if '/' in valor:
        try:
            num, den = map(float, valor.split('/'))
            return round((num / den) * 100, 2) if den != 0 else np.nan
        except:
            return np.nan

    # Caso: "83%" → 83.0
    if valor.endswith('%'):
        try:
            return float(valor.strip('%'))
        except:
            return np.nan

    # Intentar convertir a número directo
    try:
        return float(valor)
    except:
        return np.nan

# === PROCESAMIENTO ===
resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_key_games.csv", "").replace(".csv", "")
    # jugador = file.replace("_pbp_stats.csv", "").replace(".csv", "")
    # jugador = file.replace("_key_points.csv", "").replace(".csv", "")

    path = os.path.join(ruta_entrada, file)

    df = pd.read_csv(path)

    # Filtrar por años 2024 o 2025
    # df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    # df = df[df['Tournament'].isin(torneos_hard)]
    df = df[df['Tournament'].isin(torneos_clay)]

    # Limpiar todas las celdas según reglas definidas
    df = df.applymap(limpiar_celda)

    # Eliminar columnas excluidas
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir a numérico y calcular medias
    df_numeric = df.apply(pd.to_numeric, errors='coerce')
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# === GUARDAR RESULTADO ===
df_resumen = pd.DataFrame(resumen)
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
# salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# Resumen guardado en: Test_3\Juego_2019_23\clay\key_games_results3_clay.csv
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\2024903748.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\2024903748.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\2024903748.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\2024903748.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\2024903748.py:82: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %% [markdown]
# TIERRA 2024

# %%
# === CONFIGURACIÓN ===
subcarpeta = "key_games_results3"
# subcarpeta = "key_points_results3"  
# subcarpeta = "point_by_point_stats_results3"  

base_dir = "Test_3"
ruta_entrada = os.path.join(base_dir, subcarpeta)
ruta_salida = os.path.join(base_dir, "Juego_2024_25")
# ruta_salida = os.path.join(base_dir, "Juego_2019_23")
# ruta_salida_hard = os.path.join(ruta_salida, "hard")
ruta_salida_clay = os.path.join(ruta_salida, "clay")


os.makedirs(ruta_salida, exist_ok=True)

# Columnas que no deben incluirse en el cálculo de medias
columnas_excluidas = ['Date', 'Tournament', 'Rd', 'Rival', 'W_or_L']

# === FUNCIÓN DE LIMPIEZA DE CELDAS ===
def limpiar_celda(valor):
    if pd.isna(valor):
        return None
    valor = str(valor).strip()

    # Caso: "35% (6/17)" → 35.0
    if '%' in valor and '(' in valor:
        match = re.search(r'(\d+(?:\.\d+)?)%', valor)
        return float(match.group(1)) if match else None

    # Caso especial: "0/0" → NaN
    if valor == "0/0":
        return np.nan
    
    elif valor == "-":
        return np.nan

    # Caso: "6/17" → porcentaje
    if '/' in valor:
        try:
            num, den = map(float, valor.split('/'))
            return round((num / den) * 100, 2) if den != 0 else np.nan
        except:
            return np.nan

    # Caso: "83%" → 83.0
    if valor.endswith('%'):
        try:
            return float(valor.strip('%'))
        except:
            return np.nan

    # Intentar convertir a número directo
    try:
        return float(valor)
    except:
        return np.nan

# === PROCESAMIENTO ===
resumen = []

for file in os.listdir(ruta_entrada):
    if not file.endswith(".csv"):
        continue

    jugador = file.replace("_key_games.csv", "").replace(".csv", "")
    # jugador = file.replace("_pbp_stats.csv", "").replace(".csv", "")
    # jugador = file.replace("_key_points.csv", "").replace(".csv", "")
    path = os.path.join(ruta_entrada, file)

    df = pd.read_csv(path)

    # Filtrar por años 2024 o 2025
    df = df[df['Date'].astype(str).str.startswith(('2024', '2025'))]
    # df = df[df['Date'].astype(str).str.startswith(('2019', '2020', '2021', '2022', '2023'))]

    # Filtrar por torneos en superficie hard
    # df = df[df['Tournament'].isin(torneos_hard)]
    df = df[df['Tournament'].isin(torneos_clay)]

    # Limpiar todas las celdas según reglas definidas
    df = df.applymap(limpiar_celda)

    # Eliminar columnas excluidas
    df = df.drop(columns=[col for col in columnas_excluidas if col in df.columns])

    # Convertir a numérico y calcular medias
    df_numeric = df.apply(pd.to_numeric, errors='coerce')
    medias = df_numeric.mean(skipna=True).round(1)

    # Añadir nombre del jugador al inicio
    medias['Player'] = jugador
    medias = medias[['Player'] + [col for col in medias.index if col != 'Player']]

    resumen.append(medias)

# === GUARDAR RESULTADO ===
df_resumen = pd.DataFrame(resumen)
# salida_csv = os.path.join(ruta_salida, f"{subcarpeta}.csv")
# salida_csv = os.path.join(ruta_salida_hard, f"{subcarpeta}_hard.csv")
salida_csv = os.path.join(ruta_salida_clay, f"{subcarpeta}_clay.csv")
df_resumen.to_csv(salida_csv, index=False)
print(f"Resumen guardado en: {salida_csv}")
# Out:
# Resumen guardado en: Test_3\Juego_2024_25\clay\key_games_results3_clay.csv
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\3074202603.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\3074202603.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\3074202603.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\3074202603.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(limpiar_celda)
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_13592\3074202603.py:81: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
# ...

# %%
# === CONFIGURA AQUÍ la subcarpeta a combinar ===
base_dir = "Test_3/Juego_2024_25"
subcarpeta = "hard"  
ruta = os.path.join(base_dir, subcarpeta)

# === Lee y une todos los archivos CSV ===
dfs = []
for file in os.listdir(ruta):
    if file.endswith(".csv"):
        df = pd.read_csv(os.path.join(ruta, file))

        # Añadir prefijo con el nombre del archivo (sin extensión) excepto 'Player'
        # base_name = file.replace(".csv", "")
        df = df.rename(columns={col: f"{col}" for col in df.columns if col != "Player"})

        dfs.append(df)

# === Unir todos los DataFrames por 'Player' ===
df_final = dfs[0]
for df in dfs[1:]:
    df_final = pd.merge(df_final, df, on="Player", how="outer")

# === Guardar archivo combinado ===
salida = os.path.join(ruta, f"merged_{subcarpeta}.csv")
df_final.to_csv(salida, index=False)
print(f"CSV combinado guardado en: {salida}")
# Out:
# CSV combinado guardado en: Test_3/Juego_2024_25\hard\merged_hard.csv

# %%
# Carpetas base de entrada
base_dirs = ['Juego_2019_23', 'Juego_2024_25']

# Carpeta de salida raíz
output_root = 'Limpios_llm'

# Nombres de archivos
csv_files = ['merged_clay.csv', 'merged_general.csv', 'merged_hard.csv']

# Columnas a eliminar
columnas_a_eliminar = ['FH/BH', 'DR+', 'RDI', 'RDI.1', 'Slice%.1', 'RDI.2', 'Slice%.2', 'FH/GS', 'FHP/100', 'BHP/100',
                       'SvImpact.1', 'BP Wide%', 'Net Freq', 'DTL Wnr%', 'IO Wnr%', 'DTL Wnr%', 'RallyAgg',
                       'ReturnAgg', 'BP Conv/BPG', 'Hold/BPFG', 'GP Conv', 'BP Conv', 'SP Conv', 'MP Conv', 'BP Saved',
                       'SP Saved', 'MP Saved', 'TB SPW', 'TB RPW', 'BLR', 'EI', 'CBF', 'Deuce A%', 'Deuce SPW%',
                       'Ad A%', 'Ad SPW%', 'Deuce RPW%', 'Ad RPW%', 'Winners', 'UFEs', 'Ratio', 'RallyWinners',
                       'RallyUFEs', 'RallyRatio', 'Rally Wnr/Pt', 'Rally UFE/Pt', 'vs Ratio', 'FH Wnr/Pt', 'BH Wnr/Pt',
                       'BH: Wnr%', 'FH: Wnr%', 'BH Slice%', 'Slice%', 'RiP%', '2nd: RiP%', 'RiP W%.2_x', 'RetWnr%.1',
                       'Rip W%_x', 'RetWnr%', 'FHP', 'BHP', 'BP Games', 'BPF Games', 'RallyLen', '2nd: Unret%',
                       '<=3 W%.2', 'RiP W%_y', 'Unret%', 'RiP W%.2_y', 'RiP W%', '<=3 W%.1','RiP W%.1_y','RiP W%_x','DTL Wnr%.1','vs Wnr/Pt','vs UFE/Pt']

# Procesamiento
for base_dir in base_dirs:
    for csv_file in csv_files:
        ruta_csv = os.path.join(base_dir, csv_file)
        if os.path.exists(ruta_csv):
            df = pd.read_csv(ruta_csv)

            # Eliminar columnas si existen
            columnas_existentes = [col for col in columnas_a_eliminar if col in df.columns]
            df.drop(columns=columnas_existentes, inplace=True)

            # Ruta de salida
            relative_path = os.path.relpath(base_dir)
            output_dir = os.path.join(output_root, relative_path)
            os.makedirs(output_dir, exist_ok=True)

            output_path = os.path.join(output_dir, csv_file)
            df.to_csv(output_path, index=False)

            print(f"Procesado y guardado en: {output_path}")
        else:
            print(f"No encontrado: {ruta_csv}")
# Out:
# No encontrado: Limpios_llm\merged_clay.csv
