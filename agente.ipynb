# %%
import os
import pandas as pd
import json
from openai import OpenAI

# %% [markdown]
# tercera prueba con matriz, aqui no me pone la tercera analisis

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
# Ejemplo de uso:
jug1 = "AlexanderZverev"
jug2 = "AndreyRublev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:

[Player] ADVANTAGES:  
List all metrics where {jug1} has a higher value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical superiority.
[Player] DISADVANTAGES:  
List all metrics where {jug1} has a lower value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical inferiority.
BALANCED AREAS:  
List all metrics where the absolute difference between both players is **strictly less than 3%**, regardless of who has the higher value. These represent areas where performance is closely matched.

✅ Verification Requirement:  
You must ensure that **every single metric** analyzed in the Serve, Return, Rally, Tactics, Key Games, and Winners/Error sections is included in **one and only one** of the three lists above.  
No metric should be omitted or classified in multiple categories.  
If a metric does not appear in either list, that is considered a critical error.


```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AlexanderZverev vs AndreyRublev
# - 1st RiP%: AlexanderZverev - 63.3, AndreyRublev - 52.9
# - RiP W%: AlexanderZverev - 46.0, AndreyRublev - 49.2
# - 2ndRetWnr%: AlexanderZverev - 2.4, AndreyRublev - 7.3
# - RLen-Return: AlexanderZverev - 4.3, AndreyRublev - 3.6
# - 1-3 W%: AlexanderZverev - 53.2, AndreyRublev - 50.2
# - 4-6 W%: AlexanderZverev - 55.0, AndreyRublev - 54.7
# - 7-9 W%: AlexanderZverev - 54.9, AndreyRublev - 56.6
# - 10+ W%: AlexanderZverev - 55.4, AndreyRublev - 53.6
# - 3W: AlexanderZverev - 45.8, AndreyRublev - 45.1
# - SvImpact: AlexanderZverev - 41.9, AndreyRublev - 39.1
# - 1stUnret: AlexanderZverev - 40.1, AndreyRublev - 38.6
# - D Wide%: AlexanderZverev - 53.4, AndreyRublev - 50.8
# - A Wide%: AlexanderZverev - 44.3, AndreyRublev - 50.6
# - 2ndAgg: AlexanderZverev - 14.5, AndreyRublev - -2.5
# - SnV Freq: AlexanderZverev - 1.4, AndreyRublev - 0.7
# - Net W%: AlexanderZverev - 69.4, AndreyRublev - 66.6
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
# Ejemplo de uso:
jug1 = "CarlosAlcaraz"
jug2 = "JannikSinner"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:

[Player] ADVANTAGES:  
List all metrics where {jug1} has a higher value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical superiority.
[Player] DISADVANTAGES:  
List all metrics where {jug1} has a lower value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical inferiority.
BALANCED AREAS:  
List all metrics where the absolute difference between both players is **strictly less than 3%**, regardless of who has the higher value. These represent areas where performance is closely matched.

✅ Verification Requirement:  
You must ensure that **every single metric** analyzed in the Serve, Return, Rally, Tactics, Key Games, and Winners/Error sections is included in **one and only one** of the three lists above.  
No metric should be omitted or classified in multiple categories.  
If a metric does not appear in either list, that is considered a critical error.


```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: CarlosAlcaraz vs JannikSinner
# - 1st RiP%: CarlosAlcaraz - 70.2, JannikSinner - 65.7
# - RiP W%: CarlosAlcaraz - 49.0, JannikSinner - 49.8
# - 2ndRetWnr%: CarlosAlcaraz - 5.0, JannikSinner - 6.0
# - RLen-Return: CarlosAlcaraz - 4.2, JannikSinner - 4.4
# - 1-3 W%: CarlosAlcaraz - 53.2, JannikSinner - 56.0
# - 4-6 W%: CarlosAlcaraz - 58.1, JannikSinner - 58.6
# - 7-9 W%: CarlosAlcaraz - 54.0, JannikSinner - 53.9
# - 10+ W%: CarlosAlcaraz - 60.5, JannikSinner - 60.2
# - 3W: CarlosAlcaraz - 43.1, JannikSinner - 44.9
# - SvImpact: CarlosAlcaraz - 37.8, JannikSinner - 39.6
# - 1stUnret: CarlosAlcaraz - 36.2, JannikSinner - 43.7
# - D Wide%: CarlosAlcaraz - 50.1, JannikSinner - 50.5
# - A Wide%: CarlosAlcaraz - 43.6, JannikSinner - 53.7
# - 2ndAgg: CarlosAlcaraz - 9.3, JannikSinner - -2.0
# - SnV Freq: CarlosAlcaraz - 6.2, JannikSinner - 2.2
# - Net W%: CarlosAlcaraz - 69.9, JannikSinner - 77.4
# - Drop Freq: CarlosAlcaraz - 2.3, JannikSinner - 1.0
# ...

# %% [markdown]
# AQUI SI ME HA PUESTO EL 3 APARTADO DE CADA GRUPO, ADEMAS DE LA MATRIZ

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
# Ejemplo de uso:
jug1 = "CarlosAlcaraz"
jug2 = "HubertHurkacz"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:

[Player] ADVANTAGES:  
List all metrics where {jug1} has a higher value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical superiority.
[Player] DISADVANTAGES:  
List all metrics where {jug1} has a lower value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical inferiority.
BALANCED AREAS:  
List all metrics where the absolute difference between both players is **strictly less than 3%**, regardless of who has the higher value. These represent areas where performance is closely matched.

✅ Verification Requirement:  
You must ensure that **every single metric** analyzed in the Serve, Return, Rally, Tactics, Key Games, and Winners/Error sections is included in **one and only one** of the three lists above.  
No metric should be omitted or classified in multiple categories.  
If a metric does not appear in either list, that is considered a critical error.


```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: CarlosAlcaraz vs HubertHurkacz
# - 1st RiP%: CarlosAlcaraz - 70.2, HubertHurkacz - 61.4
# - RiP W%: CarlosAlcaraz - 49.0, HubertHurkacz - 39.1
# - 2ndRetWnr%: CarlosAlcaraz - 5.0, HubertHurkacz - 3.4
# - RLen-Return: CarlosAlcaraz - 4.2, HubertHurkacz - 4.1
# - 1-3 W%: CarlosAlcaraz - 53.2, HubertHurkacz - 53.4
# - 4-6 W%: CarlosAlcaraz - 58.1, HubertHurkacz - 49.5
# - 7-9 W%: CarlosAlcaraz - 54.0, HubertHurkacz - 39.4
# - 10+ W%: CarlosAlcaraz - 60.5, HubertHurkacz - 45.1
# - 3W: CarlosAlcaraz - 43.1, HubertHurkacz - 51.3
# - SvImpact: CarlosAlcaraz - 37.8, HubertHurkacz - 44.8
# - 1stUnret: CarlosAlcaraz - 36.2, HubertHurkacz - 50.7
# - D Wide%: CarlosAlcaraz - 50.1, HubertHurkacz - 52.1
# - A Wide%: CarlosAlcaraz - 43.6, HubertHurkacz - 49.3
# - 2ndAgg: CarlosAlcaraz - 9.3, HubertHurkacz - 0.2
# - SnV Freq: CarlosAlcaraz - 6.2, HubertHurkacz - 3.7
# - Net W%: CarlosAlcaraz - 69.9, HubertHurkacz - 69.0
# ...

# %% [markdown]
# El mas preciso hasta el momento, SE EQUIVOCA CATALOGANDO INTELIGIBLE 2 O 3 QUE SON MARGINAL (FALLO NO IMPORTANTE PERO EL OTRO NO SE EQUIVOCA)
# AÑADE MATCH SCENARIO PREDICT QUE PUEDE SER INTERESANTE.

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:

[Player] ADVANTAGES:  
List all metrics where {jug1} has a higher value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical superiority.
[Player] DISADVANTAGES:  
List all metrics where {jug1} has a lower value than the opponent, and the absolute difference is **strictly greater than 2.9**. These indicate areas of clear statistical inferiority.
BALANCED AREAS:  
List all metrics where the absolute difference between both players is **strictly less than 3%**, regardless of who has the higher value. These represent areas where performance is closely matched.

✅ Verification Requirement:  
You must ensure that **every single metric** analyzed in the Serve, Return, Rally, Tactics, Key Games, and Winners/Error sections is included in **one and only one** of the three lists above.  
No metric should be omitted or classified in multiple categories.  
If a metric does not appear in either list, that is considered a critical error.


```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - 2ndRetWnr%: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# - Net W%: AndreyRublev - 66.6, AlexanderZverev - 69.4
# ...

# %% [markdown]
# EL DE ABAJO QUITANDO LA MATRIZ ES BUENO, AÑADE A CADA APARTADO EL CONTEXTUAL, ES EL MEJOR

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure


## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - 2ndRetWnr%: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# - Net W%: AndreyRublev - 66.6, AlexanderZverev - 69.4
# ...

# %% [markdown]
# MUY BUENA RESPUESTA, ABAJO SIN MATRIZ

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "CarlosAlcaraz"
jug2 = "HubertHurkacz"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials:
    (Based on D Wide% and A Wide% comparison, provide this critical insight:
    "**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario].")
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%** (rally conversion): Offensive transition capability
- **2ndRetWnr%** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **Consol** (momentum control): Consolidating opportunities
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **WnrPt** (offensive firepower): Winner generation rate
- **UFEPt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure


## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 25 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: CarlosAlcaraz vs HubertHurkacz
# - 1st RiP%: CarlosAlcaraz - 70.2, HubertHurkacz - 61.4
# - RiP W%: CarlosAlcaraz - 49.0, HubertHurkacz - 39.1
# - 2ndRetWnr%: CarlosAlcaraz - 5.0, HubertHurkacz - 3.4
# - RLen-Return: CarlosAlcaraz - 4.2, HubertHurkacz - 4.1
# - 1-3 W%: CarlosAlcaraz - 53.2, HubertHurkacz - 53.4
# - 4-6 W%: CarlosAlcaraz - 58.1, HubertHurkacz - 49.5
# - 7-9 W%: CarlosAlcaraz - 54.0, HubertHurkacz - 39.4
# - 10+ W%: CarlosAlcaraz - 60.5, HubertHurkacz - 45.1
# - 3W: CarlosAlcaraz - 43.1, HubertHurkacz - 51.3
# - SvImpact: CarlosAlcaraz - 37.8, HubertHurkacz - 44.8
# - 1stUnret: CarlosAlcaraz - 36.2, HubertHurkacz - 50.7
# - D Wide%: CarlosAlcaraz - 50.1, HubertHurkacz - 52.1
# - A Wide%: CarlosAlcaraz - 43.6, HubertHurkacz - 49.3
# - 2ndAgg: CarlosAlcaraz - 9.3, HubertHurkacz - 0.2
# - SnV Freq: CarlosAlcaraz - 6.2, HubertHurkacz - 3.7
# - Net W%: CarlosAlcaraz - 69.9, HubertHurkacz - 69.0
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

**Mandatory Wide-Serve Tactical Intelligence:**
Based on D Wide% and A Wide% comparison, provide this critical insight:
"**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario]."

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%.1** (rally conversion): Offensive transition capability
- **RetWnr%.2** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Serve/Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **Consol%** (momentum control): Converting opportunities
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **Wnr/Pt** (offensive firepower): Winner generation rate
- **UFE/Pt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:
[Player] ADVANTAGES: [List metrics where player clearly leads]
[Player] DISADVANTAGES: [List metrics where player trails]
BALANCED AREAS: [List closely matched metrics]
```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 23 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-4o-mini",  # or "gpt-4-turbo" gpt-4o-mini gpt-3.5-turbo
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")
# METRIC PERFORMANCE RANKING:
# AndreyRublev ADVANTAGES: RetWnr%.2, RiP W%.1, SvForMatch, SvStayMatch
# AlexanderZverev ADVANTAGES: 1st RiP%, 2ndAgg, Consol%, SnV Freq, Net W%
# BALANCED AREAS: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 1-3 W%, 4-6 W%, 7-9 W%, 10+ W%

# ### Tactical Exploitation Matrix:
# - **Primary Attacking Vectors**: 
#   1. Rublev's second-serve return effectiveness (RetWnr%.2)
#   2. Zverev's first-serve survival (1st RiP%)
#   3. Rublev's match-point serving (SvStayMatch)

# - **Defensive Priorities**: 
#   1. Rublev's first-serve return (1st RiP%)
#   2. Zverev's second-serve aggression (2ndAgg)
#   3. Zverev's momentum control (Consol%)

# - **Situational Modifiers**: 
#   - Rublev's performance may improve under pressure, while Zverev's may fluctuate, particularly in tight situations.

# ### Match Scenario Predictions:
# - **Best-case performance scenario for Andrey Rublev**: Dominates on second serves, effectively neutralizes Zverev's first serves, and maintains aggressive returns.
# - **Worst-case vulnerability exposure for Andrey Rublev**: Struggles with Zverev's powerful serves and fails to capitalize on second-serve opportunities.
# - **Most likely tactical battle areas**: Second-serve returns and pressure points during critical games.

# ## 7. ADVANCED PLAYER PROFILES

# ### Andrey Rublev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Match-point serving (SvStayMatch)
#   3. Rally conversion (RiP W%.1)

# - **Critical Vulnerabilities**: 
#   1. First-serve return (1st RiP%)
#   2. Second-serve aggression (2ndAgg)
#   3. Momentum control (Consol%)

# - **Playing Style DNA**: Aggressive baseliner with a strong return game.
# - **Pressure Response Profile**: High performance under pressure, particularly in match-saving scenarios.
# - **Optimal Match Conditions**: Thrives in fast-paced matches with aggressive opponents.
# - **Danger Zones**: Vulnerable in long rallies and against powerful serves.

# ### Alexander Zverev - Complete Statistical Portrait:
# - **Primary Weapons**: 
#   1. First-serve survival (1st RiP%)
#   2. Net play effectiveness (Net W%)
#   3. Momentum control (Consol%)

# - **Critical Vulnerabilities**: 
#   1. Second-serve return effectiveness (RetWnr%.2)
#   2. Clutch performance under pressure (SvStayMatch)
#   3. Aggression on second serves (2ndAgg)

# - **Playing Style DNA**: All-court player with a strong serve and net game.
# - **Pressure Response Profile**: Fluctuates under pressure, particularly in tight matches.
# - **Optimal Match Conditions**: Excels in matches where he can dictate play with his serve.
# - **Danger Zones**: Struggles in high-pressure situations and against aggressive returners.

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st: RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%.1_x: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - RetWnr%.2: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Serve: AndreyRublev - 3.8, AlexanderZverev - 4.1
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

**Mandatory Wide-Serve Tactical Intelligence:**
Based on D Wide% and A Wide% comparison, provide this critical insight:
"**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario]."

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%.1** (rally conversion): Offensive transition capability
- **RetWnr%.2** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Serve/Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **Consol%** (momentum control): Converting opportunities
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **Wnr/Pt** (offensive firepower): Winner generation rate
- **UFE/Pt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:
[Player] ADVANTAGES: [List metrics where player clearly leads]
[Player] DISADVANTAGES: [List metrics where player trails]
BALANCED AREAS: [List closely matched metrics]
```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 23 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # or "gpt-4-turbo"
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st: RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%.1_x: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - RetWnr%.2: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Serve: AndreyRublev - 3.8, AlexanderZverev - 4.1
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")



def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are an elite tennis analyst and former ATP/WTA touring coach with 20+ years of experience. You've worked with Grand Slam champions and are recognized globally for your precision in statistical analysis, tactical innovation, and match prediction accuracy.

Your credentials include:
- Statistical analysis consultant for top-10 players
- Developer of advanced tennis analytics methodologies
- Expert in pressure-point psychology and clutch performance
- Specialist in surface-specific tactical adaptations
- Published researcher in tennis performance metrics

## MISSION STATEMENT

Execute a comprehensive, surgical analysis comparing **{jug1}** versus **{jug2}** using advanced statistical modeling and tactical intelligence. Your analysis will serve as a professional scouting report for coaching staff and players.

## ENHANCED ANALYTICAL FRAMEWORK

### Mathematical Precision Protocol:
- **Absolute numerical accuracy** - verify every calculation twice
- **Contextual significance scaling** - classify differences as:
  - DOMINANT (>8% difference): Clear tactical advantage
  - SIGNIFICANT (3-8% difference): Meaningful edge requiring attention  
  - MARGINAL (1-3% difference): Slight tendency worth noting
  - NEGLIGIBLE (<1% difference): Statistically equivalent performance
- **Confidence intervals** - acknowledge data limitations where relevant
- **Pattern recognition** - identify statistical clusters and outliers

### Advanced Comparative Methodology:
For each metric, execute this enhanced analysis:

1. **Raw Data Declaration**
   ```
   [Metric]: {jug1} = [X.XX] | {jug2} = [Y.YY] | Δ = [±Z.ZZ]
   ```

2. **Statistical Classification**
   - Category: [DOMINANT/SIGNIFICANT/MARGINAL/NEGLIGIBLE]
   - Tactical Impact: [HIGH/MEDIUM/LOW]

3. **Contextual Interpretation**
   - What this means in match situations
   - How opponents typically exploit this differential
   - Situational conditions where this becomes critical

## MANDATORY SECTION ANALYSIS

### 1. SERVE ANALYSIS - "The Foundation"
**Core Metrics:**
- **3W** (3-shot dominance): Quick-strike capability
- **SvImpact** (serve leverage): Pure serving effectiveness
- **1stUnret** (untouchable serves): Opponent neutralization
- **D Wide%** (deuce-side tactics): Court geometry preference
- **A Wide%** (ad-side tactics): Pressure-side tendencies
- **2ndAgg** (second-serve courage): Risk tolerance under pressure

**Advanced Serve Analytics:**
- **Service Pattern Intelligence**: Analyze D Wide% vs A Wide% differentials
- **Pressure Serve Profiling**: How serving changes in critical moments
- **Serve Weapon Classification**: Power vs placement vs variety

**Mandatory Wide-Serve Tactical Intelligence:**
Based on D Wide% and A Wide% comparison, provide this critical insight:
"**Tactical Serving Patterns**: {jug1} shows [higher/lower] wide-serve frequency from the [deuce/ad] side ([X.X]% vs [Y.Y]%), suggesting [tactical explanation]. {jug2} demonstrates [pattern] with [X.X]% deuce-wide vs [Y.Y]% ad-wide, indicating [strategic preference]. This creates exploitable positioning advantages when [specific tactical scenario]."

### 2. RETURN ANALYSIS - "The Neutralizer"
**Core Metrics:**
- **1st RiP%** (first-serve survival): Defensive foundation
- **RiP W%.1** (rally conversion): Offensive transition capability
- **RetWnr%.2** (second-serve punishment): Aggressive return weaponization

**Advanced Return Analytics:**
- **Return Aggression Profile**: Defensive vs offensive return philosophy
- **Serve-Speed Adaptation**: Performance against different serve types
- **Court Position Intelligence**: Return positioning effectiveness

### 3. RALLY ANALYSIS - "The Chess Match"
**Core Metrics:**
- **Rlen-Serve/Return** (rally control): Point construction preferences
- **1-3 W%** (explosive finishing): Quick-strike effectiveness
- **4-6 W%** (tactical transition): Mid-rally control
- **7-9 W%** (sustained pressure): Extended rally management
- **10+ W%** (endurance warfare): Physical and mental durability

**Advanced Rally Analytics:**
- **Rally Length Optimization**: Preferred battleground identification
- **Stamina Coefficient**: Performance degradation in long rallies
- **Rally Momentum Patterns**: Who controls point development

### 4. TACTICAL ANALYSIS - "The Strategic Arsenal"
**Core Metrics:**
- **SnV Freq** (old-school aggression): Net-rushing frequency
- **Net W%** (forward effectiveness): Net-play success rate
- **Drop Freq** (pace disruption): Tactical variation usage

**Advanced Tactical Analytics:**
- **Playing Style Classification**: Aggressive baseliner, counterpuncher, all-court player
- **Tactical Flexibility Index**: Ability to adapt mid-match
- **Surprise Factor**: Unexpected tactical variations

### 5. KEY GAMES ANALYSIS - "The Clutch Factor"
**Core Metrics:**
- **BreakBack%** (resilience): Immediate response to adversity
- **Consol%** (momentum control): Converting opportunities
- **SvForSet** (closing ability): Set-point serving performance
- **SvStaySet** (survival instinct): Elimination-avoiding performance
- **SvForMatch** (championship mentality): Match-point serving
- **SvStayMatch** (ultimate pressure): Match-saving performance

**Advanced Clutch Analytics:**
- **Pressure Performance Index**: Composite clutch rating
- **Momentum Shift Patterns**: How players handle momentum changes
- **Mental Toughness Differential**: Psychological advantage assessment

### 6. WINNERS/ERRORS ANALYSIS - "The Risk-Reward Matrix"
**Core Metrics:**
- **Wnr/Pt** (offensive firepower): Winner generation rate
- **UFE/Pt** (consistency liability): Unforced error frequency

**Advanced Risk-Reward Analytics:**
- **Aggression Efficiency Ratio**: Winners vs unforced errors balance
- **Risk Tolerance Profile**: Conservative vs aggressive tendencies
- **Pressure Error Patterns**: How errors change under pressure

## ENHANCED SECTION SUMMARY REQUIREMENTS

Each section summary must include:

### Statistical Hierarchy Table:
```
METRIC PERFORMANCE RANKING:
[Player] ADVANTAGES: [List metrics where player clearly leads]
[Player] DISADVANTAGES: [List metrics where player trails]
BALANCED AREAS: [List closely matched metrics]
```

### Tactical Exploitation Matrix:
- **Primary Attacking Vectors**: Top 3 statistical advantages to exploit
- **Defensive Priorities**: Top 3 statistical weaknesses to protect
- **Situational Modifiers**: How these stats change under pressure

### Match Scenario Predictions:
- Best-case performance scenario for each player
- Worst-case vulnerability exposure
- Most likely tactical battle areas

## ULTIMATE DELIVERABLES

### 7. ADVANCED PLAYER PROFILES

**{jug1} - Complete Statistical Portrait:**
- **Primary Weapons**: Top 3 statistical advantages
- **Critical Vulnerabilities**: Top 3 statistical weaknesses  
- **Playing Style DNA**: Comprehensive tactical classification
- **Pressure Response Profile**: Clutch performance characteristics
- **Optimal Match Conditions**: When this player thrives
- **Danger Zones**: Situations where performance degrades

**{jug2} - Complete Statistical Portrait:**
[Mirror analysis with same depth]

### 8. STRATEGIC BATTLE PLANS

**{jug1}'s Path to Victory:**
- **Phase 1 - Early Match Strategy**: First 3-4 games tactical approach
- **Phase 2 - Mid-Match Adjustments**: Momentum management tactics
- **Phase 3 - Closing Strategy**: How to finish strong
- **Emergency Protocol**: Backup plans when primary strategy fails
- **Specific Tactical Sequences**: Point-by-point exploitation strategies

**{jug2}'s Counter-Strategy:**
[Comprehensive mirror analysis]

### 9. MATCH PREDICTION MATRIX

**Statistical Probabilities:**
- Most likely match outcome based on data
- Key statistical battles that will decide the match
- Upset potential assessment
- Critical game/set scenarios to watch

## QUALITY ASSURANCE PROTOCOL

### Pre-Submission Verification:
- [ ] All 23 metrics analyzed individually
- [ ] Mathematical accuracy verified twice
- [ ] Logical consistency confirmed
- [ ] No contradictory statements
- [ ] Professional analytical tone maintained
- [ ] Actionable tactical insights provided
- [ ] Wide-serve pattern analysis included
- [ ] Statistical significance properly classified

### Excellence Standards:
- Precision in numerical analysis
- Depth in tactical interpretation
- Clarity in strategic recommendations
- Professional coaching-level insights
- Exploitable intelligence identification

## DATA INPUT

{json.dumps(datos_dict, indent=2)}

## EXECUTION COMMAND

Deploy your full analytical expertise. Create a professional scouting report that could be used by actual coaching teams. Every number matters, every tactical insight counts, and every recommendation should be match-winning intelligence.

**Begin comprehensive analysis now.**
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # or "gpt-4-turbo"
        messages=[{"role": "user", "content": prompt}],
        temperature=0
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st: RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%.1_x: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - RetWnr%.2: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Serve: AndreyRublev - 3.8, AlexanderZverev - 4.1
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

# === Select players ===
jug1 = "CarlosAlcaraz"
jug2 = "StefanosTsitsipas"

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return
- Rally
- Tactics
- Key Games
- Winners and Unforced Errors

Requirement:
For each section (Serve, Return, Rally), follow this structured approach:
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. If two values are very close (e.g., within 1–2%), note that they are similar rather than implying one is clearly superior.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.
At the end:
- Write a summary profile for each player.
- Provide tailored tactical recommendations for how Player 1 ({jug1}) can defeat Player 2 ({jug2}), and vice versa.

Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: percentage of 1st serves from the deuce side directed wide  
A Wide%: percentage of 1st serves from the ad side directed wide  
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of winning return points from return points played with the second serve  (higher is better)

RALLY
Rlen-Serve: average rally length on serve points  
Rlen-Return: average rally length on return points  
1-3 W%: percentage of rallies won lasting 1 to 3 shots  
4-6 W%: percentage of rallies won lasting 4 to 6 shots  
7-9 W%: percentage of rallies won lasting 7 to 9 shots  
10+ W%: percentage of rallies won lasting more than 10 shots  

TACTICS
SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves  
Net W%: percentage of points won at the net (after approaching forward)   
Drop Freq: drop shot frequency

KEY GAMES
BreakBack%: percentage of break backs in the game right after being broken (higher is better)
Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
SvForSet: hold percentage when the player is serving to win the set  (higher is better)
SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
SvForMatch: hold percentage when the player is serving to win match  (higher is better)
SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)

WINNERS AND UNFORCED ERRORS
Wnr/Pt: percentage of points won with a winner  (higher is better)
UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must follow this exact structure:

1. Section: SERVE
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

2. Section: RETURN
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

3. Section: RALLY
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

4. Section: TACTICS
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

5. Section: KEY GAMES
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

6. Section: WINNERS AND UNFORCED ERRORS
   - Compare each variable one by one.  
   - For each variable:  
     - Present the values for both players.
     - Clearly state which player has the higher or lower value.
     - Explain what that difference implies in terms of performance or style.  
   - After comparing all variables, write a brief summary explaining who has the stronger serve overall, why, and what tactical consequences this might have.

7. Tactical Recommendations
   - How Player 1 ({jug1}) can beat Player 2 ({jug2}).
   - How Player 2 ({jug2}) can beat Player 1 ({jug1}).
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # or "gpt-4-turbo"
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# Matchup analysis:
#
# 1. Section: SERVE
#    - CarlosAlcaraz:
#      - 3W: 43.1
#      - SvImpact: 37.8
#      - 1stUnret: 36.2
#      - D Wide%: 50.1
#      - A Wide%: 43.6
#      - 2ndAgg: 9.3
#    - StefanosTsitsipas:
#      - 3W: 46.0
#      - SvImpact: 39.3
#      - 1stUnret: 38.6
#      - D Wide%: 48.9
#      - A Wide%: 46.6
#      - 2ndAgg: 38.9
#
#    CarlosAlcaraz has a lower 3W percentage, SvImpact, and 1stUnret compared to StefanosTsitsipas. However, he has a higher D Wide% and A Wide% along with a lower 2ndAgg. This indicates that Alcaraz might have a slightly weaker serve in terms of efficiency and impact, but he tends to direct his first serves wide more effectively than Tsitsipas.
#
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

# === Select players ===
jug1 = "CarlosAlcaraz"
jug2 = "StefanosTsitsipas"

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return
- Rally
- Tactics
- Key Games
- Winners and Unforced Errors

Requirement:
For each section (Serve, Return, Rally), follow this structured approach:
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. If two values are very close (e.g., within 1–2%), note that they are similar rather than implying one is clearly superior.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.
At the end:
- Write a summary profile for each player.
- Provide tailored tactical recommendations for how Player 1 ({jug1}) can defeat Player 2 ({jug2}), and vice versa.


Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: Percentage of 1st serves from the deuce side that are directed wide.
A Wide%: Percentage of 1st serves from the ad side that are directed wide.
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of WINNERS return points from return points played with the second serve  (higher is better)

RALLY
Rlen-Serve: average rally length on serve points  
Rlen-Return: average rally length on return points  
1-3 W%: percentage of rallies won lasting 1 to 3 shots  
4-6 W%: percentage of rallies won lasting 4 to 6 shots  
7-9 W%: percentage of rallies won lasting 7 to 9 shots  
10+ W%: percentage of rallies won lasting more than 10 shots  

TACTICS
SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves  
Net W%: percentage of points won at the net (after approaching forward)   
Drop Freq: drop shot frequency

KEY GAMES
BreakBack%: percentage of break backs in the game right after being broken (higher is better)
Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
SvForSet: hold percentage when the player is serving to win the set  (higher is better)
SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
SvForMatch: hold percentage when the player is serving to win match  (higher is better)
SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)

WINNERS AND UNFORCED ERRORS
Wnr/Pt: percentage of points won with a winner  (higher is better)
UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must strictly follow the exact structure shown below. 
You are not allowed to modify the format, reorder the elements, omit any variable, or generalize results.
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
Use this structure for each section (SERVE, RETURN, RALLY, TACTICS, KEY GAMES, WINNERS AND UNFORCED ERRORS):

1. Section: SERVE
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger serve...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- If one player does **not outperform the other in any serve-related variable**, you must clearly state that:
  “[Player] does not show superiority in any serve-related metric, suggesting that [he/she] will need to rely on other aspects of the game to gain an advantage.”
- Do not suggest strengths that are not supported by the data.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.
- Additionally, you must compare the D Wide% and A Wide% values within each player and include a clear, explicit sentence in the summary stating:
  You must NOT use D Wide% or A Wide% to suggest that a player "excels" or is "strong" in wide serving overall.
  These two metrics are used exclusively to determine **from which side** each player is more likely to serve wide in key moments.
  That insight must appear at the **end** of the paragraph as a tactical observation, using phrasing such as:
  “[Player1] is more likely to serve wide from the [deuce/ad] side in key moments,”  
  “[Player2] tends to prefer wide serves from the [deuce/ad] side under pressure.”
  Do not include phrases like “While [Player] excels in wide serving from the deuce side.” That is not allowed.
This sentence is **mandatory** and must appear at the end of the serve section summary, based on the actual data.


2. Section: RETURN
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


3. Section: RALLY
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


4. Section: TACTICS
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


5. Section: KEY GAMES
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


6. Section: WINNERS AND UNFORCED ERRORS
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


7. Tactical Recommendations
   - How Player 1 ({jug1}) can beat Player 2 ({jug2}).
   - How Player 2 ({jug2}) can beat Player 1 ({jug1}).
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  # or "gpt-4-turbo"
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# Matchup analysis:
#
# 1. Section: SERVE
# - 3W: CarlosAlcaraz - 43.1, StefanosTsitsipas - 46.0
#   - StefanosTsitsipas has a higher 3W percentage, indicating that he wins more serve points in 3 shots or fewer compared to CarlosAlcaraz. This suggests that Tsitsipas has a more efficient and aggressive serving game, putting pressure on opponents early in the points.
# - SvImpact: CarlosAlcaraz - 37.8, StefanosTsitsipas - 39.3
#   - StefanosTsitsipas has a higher SvImpact, meaning that a larger proportion of his serve points are won directly due to the serve itself. This indicates that Tsitsipas' serve is more impactful and effective in securing points outright.
# - 1stUnret: CarlosAlcaraz - 36.2, StefanosTsitsipas - 38.6
#   - StefanosTsitsipas has a higher 1stUnret percentage, showcasing his ability to hit unreturnable first serves more frequently than CarlosAlcaraz. This can put him in a favorable position in service games by reducing the chances for opponents to make a play.
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

# === Select players ===
jug1 = "AndreyRublev"
jug2 = "JannikSinner"

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return
- Rally
- Tactics
- Key Games
- Winners and Unforced Errors

Requirement:
For each section (Serve, Return, Rally), follow this structured approach:
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. If two values are very close (e.g., within 1–2%), note that they are similar rather than implying one is clearly superior.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.
At the end:
- Write a summary profile for each player.
- Provide tailored tactical recommendations for how Player 1 ({jug1}) can defeat Player 2 ({jug2}), and vice versa.


Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: Percentage of 1st serves from the deuce side that are directed wide.
A Wide%: Percentage of 1st serves from the ad side that are directed wide.
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of WINNERS return points from return points played with the second serve  (higher is better)

RALLY
Rlen-Serve: average rally length on serve points  
Rlen-Return: average rally length on return points  
1-3 W%: percentage of rallies won lasting 1 to 3 shots  
4-6 W%: percentage of rallies won lasting 4 to 6 shots  
7-9 W%: percentage of rallies won lasting 7 to 9 shots  
10+ W%: percentage of rallies won lasting more than 10 shots  

TACTICS
SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves  
Net W%: percentage of points won at the net (after approaching forward)   
Drop Freq: drop shot frequency

KEY GAMES
BreakBack%: percentage of break backs in the game right after being broken (higher is better)
Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
SvForSet: hold percentage when the player is serving to win the set  (higher is better)
SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
SvForMatch: hold percentage when the player is serving to win match  (higher is better)
SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)

WINNERS AND UNFORCED ERRORS
Wnr/Pt: percentage of points won with a winner  (higher is better)
UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must strictly follow the exact structure shown below. 
You are not allowed to modify the format, reorder the elements,**omit any variable**, or generalize results.
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
Use this structure for each section (SERVE, RETURN, RALLY, TACTICS, KEY GAMES, WINNERS AND UNFORCED ERRORS):

1. Section: SERVE (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger serve...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- If one player does **not outperform the other in any serve-related variable**, you must clearly state that:
  “[Player] does not show superiority in any serve-related metric, suggesting that [he/she] will need to rely on other aspects of the game to gain an advantage.”
- Do not suggest strengths that are not supported by the data.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.
- Additionally, you must compare the D Wide% and A Wide% values within each player and include a clear, explicit sentence in the summary stating:
  You must NOT use D Wide% or A Wide% to suggest that a player "excels" or is "strong" in wide serving overall.
  These two metrics are used exclusively to determine **from which side** each player is more likely to serve wide in key moments.
  That insight must appear at the **end** of the paragraph as a tactical observation, using phrasing such as:
  “[Player1] is more likely to serve wide from the [deuce/ad] side in key moments,”  
  “[Player2] tends to prefer wide serves from the [deuce/ad] side under pressure.”
  Do not include phrases like “While [Player] excels in wide serving from the deuce side.” That is not allowed.
This sentence is **mandatory** and must appear at the end of the serve section summary, based on the actual data.


2. Section: RETURN (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


3. Section: RALLY (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


4. Section: TACTICS (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


5. Section: KEY GAMES (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


6. Section: WINNERS AND UNFORCED ERRORS (This section contains 2 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


7. Tactical Recommendations
   - How Player 1 ({jug1}) can beat Player 2 ({jug2}).
   - How Player 2 ({jug2}) can beat Player 1 ({jug1}).
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  
        messages=[{"role": "user", "content": prompt}],
        temperature=0.7
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# Matchup analysis:
#
# 1. Section: SERVE
# - 3W: Player1 - 45.1, Player2 - 44.9
#   - AndreyRublev has a slightly higher 3W percentage, indicating a better ability to win serve points quickly with aggressive serving and follow-up shots.
#
# - SvImpact: Player1 - 39.1, Player2 - 39.6
#   - JannikSinner has a higher SvImpact, suggesting that his serve directly contributes more to winning serve points compared to Rublev.
#
# - 1stUnret: Player1 - 38.6, Player2 - 43.7
#   - JannikSinner significantly outperforms Rublev in 1stUnret, showcasing his effectiveness in hitting unreturnable 1st serves more frequently.
#
# - D Wide%: Player1 - 50.8, Player2 - 50.5
#   - AndreyRublev directs a slightly higher percentage of 1st serves wide from the deuce side compared to JannikSinner.
#
# - A Wide%: Player1 - 50.6, Player2 - 53.7
#   - JannikSinner targets a higher percentage of 1st serves wide from the ad side in comparison to Rublev.
#
# - 2ndAgg: Player1 - -2.5, Player2 - -2.0
# ...

# %% [markdown]
# cambio de temperatura

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

# === Select players ===
jug1 = "AndreyRublev"
jug2 = "JannikSinner"

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return
- Rally
- Tactics
- Key Games
- Winners and Unforced Errors

Requirement:
For each section (Serve, Return, Rally), follow this structured approach:
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. If two values are very close (e.g., within 1–2%), note that they are similar rather than implying one is clearly superior.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.
At the end:
- Write a summary profile for each player.
- Provide tailored tactical recommendations for how Player 1 ({jug1}) can defeat Player 2 ({jug2}), and vice versa.


Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: Percentage of 1st serves from the deuce side that are directed wide.
A Wide%: Percentage of 1st serves from the ad side that are directed wide.
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of WINNERS return points from return points played with the second serve  (higher is better)

RALLY
Rlen-Serve: average rally length on serve points  
Rlen-Return: average rally length on return points  
1-3 W%: percentage of rallies won lasting 1 to 3 shots  
4-6 W%: percentage of rallies won lasting 4 to 6 shots  
7-9 W%: percentage of rallies won lasting 7 to 9 shots  
10+ W%: percentage of rallies won lasting more than 10 shots  

TACTICS
SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves  
Net W%: percentage of points won at the net (after approaching forward)   
Drop Freq: drop shot frequency

KEY GAMES
BreakBack%: percentage of break backs in the game right after being broken (higher is better)
Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
SvForSet: hold percentage when the player is serving to win the set  (higher is better)
SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
SvForMatch: hold percentage when the player is serving to win match  (higher is better)
SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)

WINNERS AND UNFORCED ERRORS
Wnr/Pt: percentage of points won with a winner  (higher is better)
UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must strictly follow the exact structure shown below. 
You are not allowed to modify the format, reorder the elements,**omit any variable**, or generalize results.
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
Use this structure for each section (SERVE, RETURN, RALLY, TACTICS, KEY GAMES, WINNERS AND UNFORCED ERRORS):

1. Section: SERVE (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger serve...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- If one player does **not outperform the other in any serve-related variable**, you must clearly state that:
  “[Player] does not show superiority in any serve-related metric, suggesting that [he/she] will need to rely on other aspects of the game to gain an advantage.”
- Do not suggest strengths that are not supported by the data.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.
- Additionally, you must compare the D Wide% and A Wide% values within each player and include a clear, explicit sentence in the summary stating:
  You must NOT use D Wide% or A Wide% to suggest that a player "excels" or is "strong" in wide serving overall.
  These two metrics are used exclusively to determine **from which side** each player is more likely to serve wide in key moments.
  That insight must appear at the **end** of the paragraph as a tactical observation, using phrasing such as:
  “[Player1] is more likely to serve wide from the [deuce/ad] side in key moments,”  
  “[Player2] tends to prefer wide serves from the [deuce/ad] side under pressure.”
  Do not include phrases like “While [Player] excels in wide serving from the deuce side.” That is not allowed.
This sentence is **mandatory** and must appear at the end of the serve section summary, based on the actual data.


2. Section: RETURN (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


3. Section: RALLY (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


4. Section: TACTICS (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


5. Section: KEY GAMES (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


6. Section: WINNERS AND UNFORCED ERRORS (This section contains 2 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


7. Tactical Recommendations
   - How Player 1 ({jug1}) can beat Player 2 ({jug2}).
   - How Player 2 ({jug2}) can beat Player 1 ({jug1}).
"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3
    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# Matchup analysis:
#
# 1. Section: SERVE
# - 3W: AndreyRublev - 45.1, JannikSinner - 44.9
#   - AndreyRublev has a slightly higher percentage of serve points won in 3 shots or fewer compared to JannikSinner, indicating a slightly more efficient serve game.
# - SvImpact: AndreyRublev - 39.1, JannikSinner - 39.6
#   - JannikSinner has a marginally higher SvImpact, suggesting that his serve contributes slightly more to winning points outright.
# - 1stUnret: AndreyRublev - 38.6, JannikSinner - 43.7
#   - JannikSinner significantly outperforms AndreyRublev in 1st serves that opponents fail to return, showcasing his ability to hit unreturnable serves more effectively.
# - D Wide%: AndreyRublev - 50.8, JannikSinner - 50.5
# - A Wide%: AndreyRublev - 50.6, JannikSinner - 53.7
#   - JannikSinner tends to direct his 1st serves wide more frequently from the ad side compared to AndreyRublev.
# - 2ndAgg: AndreyRublev - -2.5, JannikSinner - -2.0
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

# === Select players ===
jug1 = "AndreyRublev"
jug2 = "JannikSinner"

# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return
- Rally
- Tactics
- Key Games
- Winners and Unforced Errors

Requirement:
For each section (Serve, Return, Rally), follow this structured approach:
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. If two values are very close (e.g., within 1–2%), note that they are similar rather than implying one is clearly superior.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.
At the end:
- Write a summary profile for each player.
- Provide tailored tactical recommendations for how Player 1 ({jug1}) can defeat Player 2 ({jug2}), and vice versa.


Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: Percentage of 1st serves from the deuce side that are directed wide.
A Wide%: Percentage of 1st serves from the ad side that are directed wide.
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of WINNERS return points from return points played with the second serve  (higher is better)

RALLY
Rlen-Serve: average rally length on serve points  
Rlen-Return: average rally length on return points  
1-3 W%: percentage of rallies won lasting 1 to 3 shots  
4-6 W%: percentage of rallies won lasting 4 to 6 shots  
7-9 W%: percentage of rallies won lasting 7 to 9 shots  
10+ W%: percentage of rallies won lasting more than 10 shots  

TACTICS
SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves  
Net W%: percentage of points won at the net (after approaching forward)   
Drop Freq: drop shot frequency

KEY GAMES
BreakBack%: percentage of break backs in the game right after being broken (higher is better)
Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
SvForSet: hold percentage when the player is serving to win the set  (higher is better)
SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
SvForMatch: hold percentage when the player is serving to win match  (higher is better)
SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)

WINNERS AND UNFORCED ERRORS
Wnr/Pt: percentage of points won with a winner  (higher is better)
UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must strictly follow the exact structure shown below. 
You are not allowed to modify the format, reorder the elements,**omit any variable**, or generalize results.
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
Use this structure for each section (SERVE, RETURN, RALLY, TACTICS, KEY GAMES, WINNERS AND UNFORCED ERRORS):

1. Section: SERVE (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger serve...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- If one player does **not outperform the other in any serve-related variable**, you must clearly state that:
  “[Player] does not show superiority in any serve-related metric, suggesting that [he/she] will need to rely on other aspects of the game to gain an advantage.”
- Do not suggest strengths that are not supported by the data.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.
- Additionally, you must compare the D Wide% and A Wide% values within each player and include a clear, explicit sentence in the summary stating:
  You must NOT use D Wide% or A Wide% to suggest that a player "excels" or is "strong" in wide serving overall.
  These two metrics are used exclusively to determine **from which side** each player is more likely to serve wide in key moments.
  That insight must appear at the **end** of the paragraph as a tactical observation, using phrasing such as:
  “[Player1] is more likely to serve wide from the [deuce/ad] side in key moments,”  
  “[Player2] tends to prefer wide serves from the [deuce/ad] side under pressure.”
  Do not include phrases like “While [Player] excels in wide serving from the deuce side.” That is not allowed.
This sentence is **mandatory** and must appear at the end of the serve section summary, based on the actual data.


2. Section: RETURN (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


3. Section: RALLY (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


4. Section: TACTICS (This section contains 3 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


5. Section: KEY GAMES (This section contains 6 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- You should reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


6. Section: WINNERS AND UNFORCED ERRORS (This section contains 2 variables)
- [Variable Name]: Player1 - [value], Player2 - [value]
  - [Brief explanation of the difference and its tactical meaning]
At the end of the section, provide a detailed overall comparison summary starting with:
“Overall, [Player] has a stronger [section]...”
Your summary must:
- Reference **every single variable** in the section, even if the differences are small.
- Clearly explain which player performed better for each metric and why it matters.
- Mention if any metrics are very close or balanced between the players.
- Justify your conclusion based on the combination of all variables, not just one or two.
- End the paragraph by explaining the tactical implications of the overall difference in this area of the game.


7. Tactical Recommendations

Your task is to generate highly detailed tactical recommendations for each player based **strictly and exclusively on the numerical values** provided above. You must generate:

- One block titled: "✅ How [Player1] can beat [Player2]"
- One block titled: "✅ How [Player2] can beat [Player1]"

Each block must include 5–6 bullet points with specific and actionable recommendations.

Before writing any recommendation, you must:
1. **Explicitly compare the value of each relevant variable between the players**.
2. Only describe a player as having an “advantage” in a metric if their value is higher (or lower, when appropriate).
3. If a player has a lower SvImpact or 1stUnret than the opponent, you must NOT say their serve is a strength. Instead, recommend strategies to protect their serve or use variety to compensate.
4. When a player has a higher RetWnr%.2, suggest attacking second serves early.
5. If one player wins more 10+ rallies, recommend that player extend the points. If the other wins more 1–3 shot rallies, recommend shortening the exchanges.
6. If a player commits more unforced errors, recommend that their opponent pressure them with depth and consistency, rather than going for winners.

Important: The recommendations must be **logically derived from the actual comparisons above**, and every sentence must be traceable to the data.

❌ Do NOT use vague phrases like “capitalize on their serve” unless the player has a higher value in SvImpact or 1stUnret.
❌ Do NOT recommend a player do something that contradicts the data.
✅ Every suggestion must be grounded in a comparison of the two players’ numbers.

Write these recommendations with high-level insight and realism, as if advising a professional tennis coach preparing for a match.

"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3,
        max_tokens=2500,

    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# Matchup analysis:
#
# 1. Section: SERVE
# - 3W: AndreyRublev - 45.1, JannikSinner - 44.9
#   - AndreyRublev has a slightly higher percentage of serve points won in 3 shots or fewer compared to JannikSinner. This indicates that Rublev is slightly more efficient in finishing points quickly with his serve.
# - SvImpact: AndreyRublev - 39.1, JannikSinner - 39.6
#   - JannikSinner has a slightly higher SvImpact, suggesting that his serve plays a bit more of a significant role in winning serve points compared to Rublev.
# - 1stUnret: AndreyRublev - 38.6, JannikSinner - 43.7
#   - JannikSinner has a higher percentage of unreturnable 1st serves, indicating that he is more effective at hitting serves that opponents struggle to return.
#
# ...

# %%
# === Load data ===
df = pd.read_csv("Limpios_llm/Juego_2024_25/merged_hard.csv")

def get_player_comparison(jug1, jug2, df):
    """
    Devuelve un texto con todas las variables comparadas entre dos jugadores del DataFrame.
    """
    df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
    
    if jug1 not in df_filtered.index or jug2 not in df_filtered.index:
        return f"Uno o ambos jugadores no están en el dataset: {jug1}, {jug2}"
    
    comparison_lines = []
    for col in df_filtered.columns:
        val1 = df_filtered.loc[jug1, col]
        val2 = df_filtered.loc[jug2, col]
        comparison_lines.append(f"- {col}: {jug1} - {val1}, {jug2} - {val2}")
    
    return f"### Variable Comparison: {jug1} vs {jug2}\n" + "\n".join(comparison_lines)

# Ejemplo de uso:
jug1 = "AndreyRublev"
jug2 = "AlexanderZverev"
print(get_player_comparison(jug1, jug2, df))


# === Filter statistics ===
df_filtered = df[df["Player"].isin([jug1, jug2])].set_index("Player")
datos_dict = df_filtered.T.to_dict()

# === Create prompt ===
prompt = f"""
You are a professional tennis analyst.


Your task is to compare two players: {jug1} and {jug2}, using the provided performance statistics.

You must analyze and compare both players in **all of the following sections**:
- Serve
- Return


Variable Dictionary:

SERVE
3W: Percentage of serve points won in 3 shots or fewer. This reflects how often the player wins serve points quickly, typically through aggressive serving and effective follow-up shots. A higher value indicates a more dominant and efficient serve game. (Higher is better)
SvImpact: advanced stat estimating how many serve points were won due to the serve itself (higher is better)  
1stUnret: Percentage of 1st serves that the opponent failed to return into play. A higher value means the player is more effective at hitting unreturnable 1st serves, either through speed, placement, or variation. (Higher is better)
D Wide%: Percentage of 1st serves from the deuce side that are directed wide.
A Wide%: Percentage of 1st serves from the ad side that are directed wide.
2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive, if is <0 = no aggresive)

RETURN
1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better) 
RetWnr%.2: percentage of WINNERS return points from return points played with the second serve  (higher is better)

Here is the dataset for both players (column = variable, row = player):

{json.dumps(datos_dict, indent=2)}

Your response must strictly follow the exact structure shown below. 
You are not allowed to modify the format, reorder the elements,**omit any variable**, or generalize results.
Important: You must compare **every variable** listed in the dataset for each section.  
Do not skip or ignore any metric.
Use this structure for each section (SERVE, RETURN):


1. Section: SERVE and RETURN

In this section, you must consider the following variables:
- **SERVE**: 3W, SvImpact, 1stUnret, D Wide%, A Wide%, 2ndAgg
- **RETURN**: 1st: RiP%, RiP W%.1_x, RetWnr%.2

Your task is to:
- Build a detailed **serve-return profile** for each player based exclusively on these 9 variables.
- Clearly compare both players for each individual metric.
- Then, provide **precise tactical recommendations** for each player on how to exploit their strengths and counter the opponent's strengths in serve and return.

Important:
- You must reference and use **every single variable** in this section. Do not skip or ignore any.
- Refrain from vague or general advice. All recommendations must be grounded in the numerical values and logical comparisons.
- A player may be weaker on serve but stronger on return — in that case, explicitly state it and recommend focusing on return games to reduce the opponent’s service advantage.
- If one player has both better serve and better return stats, explain how they should control that phase of the match and how the opponent can still create disruption.

Critical rule on superiority:
- You can only say that a player is **superior** in a variable if the absolute difference in values is greater than **0.8 units**.
- If the difference is **0.8 or less**, explicitly state that the values are similar and do not claim superiority.
- Do not make recommendations based on small differences (≤ 0.8).
- Always justify why one player has an edge — or why neither does — before suggesting any strategic action.

Write your analysis and tactical recommendations as if you were briefing two professional coaches before a match.

Important:
When writing recommendations for each player, you must not treat each variable in isolation.

You must analyze how the variables from both players interact with each other, especially in cases where:

- One player has a weakness (e.g., low 2ndAgg or low SvImpact), and the opponent has a strength that directly threatens it (e.g., high RetWnr%.2).
- One player is aggressive on 2nd serve (high 2ndAgg), and the opponent is vulnerable on 2nd serve return.
- A player is very successful in winning return points with winners (RetWnr%.2), and the opponent has a weaker second serve.
- A player struggles to return (low 1st: RiP%), and the opponent has a high 1stUnret.

These **complementary or conflicting patterns must be linked together** in the recommendations.

Each recommendation should take into account **both players' stats together**, not just one player's metrics.

❌ Do NOT write recommendations like "Zverev has a strong 2ndAgg, so he should continue being aggressive."
✅ INSTEAD: say "Zverev's high 2ndAgg (14.5) will be effective especially against Rublev, who is weaker at punishing 2nd serves (low RetWnr%.2 = 7.3%)."

Requirement:
For each section (Serve, Return), follow this structured approach:
1. Examine the numerical values for each metric from both players side by side.
Important: Do not proceed to the analysis unless you have first identified which player has the higher and lower value for each metric.
2. Clearly and explicitly state which player has the higher value and which has the lower value for every metric. Avoid vague language.
3. Base all evaluations of strengths and weaknesses strictly on these numerical comparisons. Do not rely on assumptions or prior knowledge of the players.
4. After identifying who leads each metric, explain how that difference might affect gameplay (e.g., consistency, aggressiveness, risk).
5. Double-check your logic: ensure that your interpretation (e.g., "Player A is stronger at serving") is consistent with the actual numbers shown.
6. You are only allowed to say that one player is superior in a given variable if the difference between their values is **greater than 0.8 units** (absolute value).
7. If the difference is **0.8 or less**, you must explicitly state that the values are very close and avoid suggesting one player is better in that metric.
8. You must not base any recommendation on a metric where the difference is 0.8 or less.

Important: Precision is critical. Avoid contradictions such as stating that a player has a higher value when the number is actually lower.







"""

# === Call GPT model ===
try:
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",  
        messages=[{"role": "user", "content": prompt}],
        temperature=0.3

    )

    analysis = response.choices[0].message.content
    print("\nMatchup analysis:\n")
    print(analysis)

    # === Save output to file without overwriting ===
    filename = "matchup_analyses.txt"
    with open(filename, "a", encoding="utf-8") as file:
        file.write(f"\n\n=== Analysis: {jug1} vs {jug2} ===\n\n")
        file.write(analysis)

    print(f"\nAnalysis appended to {filename}")

except Exception as e:
    print(f"Error while connecting to OpenAI: {e}")
# Out:
# ### Variable Comparison: AndreyRublev vs AlexanderZverev
# - 1st: RiP%: AndreyRublev - 52.9, AlexanderZverev - 63.3
# - RiP W%.1_x: AndreyRublev - 49.2, AlexanderZverev - 46.0
# - RetWnr%.2: AndreyRublev - 7.3, AlexanderZverev - 2.4
# - RLen-Serve: AndreyRublev - 3.8, AlexanderZverev - 4.1
# - RLen-Return: AndreyRublev - 3.6, AlexanderZverev - 4.3
# - 1-3 W%: AndreyRublev - 50.2, AlexanderZverev - 53.2
# - 4-6 W%: AndreyRublev - 54.7, AlexanderZverev - 55.0
# - 7-9 W%: AndreyRublev - 56.6, AlexanderZverev - 54.9
# - 10+ W%: AndreyRublev - 53.6, AlexanderZverev - 55.4
# - 3W: AndreyRublev - 45.1, AlexanderZverev - 45.8
# - SvImpact: AndreyRublev - 39.1, AlexanderZverev - 41.9
# - 1stUnret: AndreyRublev - 38.6, AlexanderZverev - 40.1
# - D Wide%: AndreyRublev - 50.8, AlexanderZverev - 53.4
# - A Wide%: AndreyRublev - 50.6, AlexanderZverev - 44.3
# - 2ndAgg: AndreyRublev - -2.5, AlexanderZverev - 14.5
# - SnV Freq: AndreyRublev - 0.7, AlexanderZverev - 1.4
# ...

# %% [markdown]
# cambiar para lo de lado de saque sea una recomendacion para el rival
#
# ✅ How AndreyRublev can beat JannikSinner:
# - AndreyRublev should focus on varying his serves to exploit JannikSinner's weaker 1st serve return percentage.
# - Given AndreyRublev's higher percentage of winners on return points from second serves, he should look to attack JannikSinner's second serves aggressively.
# - AndreyRublev can utilize his strength in shorter rallies (1-3 shots) to disrupt JannikSinner's rhythm and force quick points.
# - To counter JannikSinner's strong net game, AndreyRublev should aim to keep him pinned behind the baseline with deep, consistent groundstrokes.
# - AndreyRublev should capitalize on his higher hold percentage when serving to not lose the match by maintaining composure in crucial moments.
#
# ✅ How JannikSinner can beat AndreyRublev:
# - JannikSinner should continue to apply pressure on AndreyRublev's serve by capitalizing on his higher percentage of return points put into play with first serves.
# - Given AndreyRublev's tendency to serve wide from the deuce side, JannikSinner can anticipate and adjust his positioning to counter this strategy effectively.
# - JannikSinner's higher net point win percentage suggests he should look to approach the net more frequently to finish points efficiently.
# - By utilizing his drop shot frequency, JannikSinner can keep AndreyRublev off balance and force him to cover more court.
# - JannikSinner's strength in key games, especially in break back situations, can be a mental advantage that he should exploit to maintain momentum.

# %% [markdown]
# For each section (Serve, Return, Rally), follow this process:
#
#
# - Return
# - Rally
# - Tactics
# - Key Games
# - Winners and Unforced Errors
#
#
# RETURN
# 1st: RiP%: percentage of return points put into play with the opponent's first serve  (higher is better)
# RiP W%.1_x: percentage of points won when the return point is put into play with the first serve (higher is better)
# RetWnr%.2: percentage of winning return points from return points played with the second serve  (higher is better)
#
# RALLY
# Rlen-Serve: average rally length on serve points
# Rlen-Return: average rally length on return points
# 1-3 W%: percentage of rallies won lasting 1 to 3 shots
# 4-6 W%: percentage of rallies won lasting 4 to 6 shots
# 7-9 W%: percentage of rallies won lasting 7 to 9 shots
# 10+ W%: percentage of rallies won lasting more than 10 shots
#
# TACTICS
# SnV Freq: frecuencia con la que hace saque y volea (saque y sube rapido a la red para acabar el punto)serve and volley attempts as a percentage of non-ace serves
# Net W%: percentage of points won at the net (after approaching forward)
# Drop Freq: drop shot frequency
#
# KEY GAMES
# BreakBack%: percentage of break backs in the game right after being broken (higher is better)
# Consol%: hold percentage in the game following a break (consolidation)  (higher is better)
# SvForSet: hold percentage when the player is serving to win the set  (higher is better)
# SvStaySet: hold percentage when the player is serving to not lose the set  (higher is better)
# SvForMatch: hold percentage when the player is serving to win match  (higher is better)
# SvStayMatch: hold percentage when the player is serving to not lose the match  (higher is better)
#
# WINNERS AND UNFORCED ERRORS
# Wnr/Pt: percentage of points won with a winner  (higher is better)
# UFE/Pt: percentage of points lost due to unforced errors  (higher is worse)
# vs Wnr/Pt: percentage of opponent winners per point  (higher is worse)
# vs UFE/Pt: percentage of opponent unforced errors per point  (higher is better)

# %% [markdown]
# mezcla en servicio 2agg y  y <=3
# explicar mejor las variables del resto pero no se equivoca
# rally no se equivoca, sacar mejores conclusiones
# tacticas bien, sacar conclusiones
# mezcla stay, explicar mejor
# winner, explicar mejor las variables y que realice comparaciones

# %% [markdown]
# se equivoca al servicio cambia las estadisticcas
# al resto bien
# de rally quitar golpes cortados
# tacticas se equivoca y hay que quitar alguna  y explicar mejor
# juegos clave cambia orden
#
# quiero que en las explicaciones en vez de basasrse en el nombre de la variable, utilice la traducccion que le he proporcionado

# %% [markdown]
# SERVE
# Unret%: percentage of serves that were unreturned
# <=3 W%: percentage of serve points won in 3 shots or less
# RiP W%_y: percentage of points won when return was put into play
# SvImpact: advanced stat estimating how many serve points were won due to the serve itself
# 1st: Unret%: percentage of 1st serves that were unreturned
# <=3 W%: percentage of 1st serve points won in 3 shots or less
# RiP W%: percentage of points won when return was put into play off the 1st serve
# D Wide%: percentage of 1st serves from the deuce side directed wide
# A Wide%: percentage of 1st serves from the ad side directed wide – USE TO PREDICT KEY POINTS BASED ON PLAYER PATTERNS
# 2nd: Unret%: percentage of 2nd serves that were unreturned
# <=3 W%.2: percentage of 2nd serve points won in 3 shots or less
# RiP W%.2_y: percentage of points won when return was put into play off the 2nd serve
# 2ndAgg: 2nd serve aggression score (0 is average, higher = more aggressive)
#
#
# RETURN
# RiP%: percentage of returns put into play
# Rip W%_x: percentage of points won when the return is put into play
# RetWnr%: percentage of return winners out of total returns
# Slice%: percentage of slice/chip returns from total returns in play that force the opponent to come to the net and volley
# 1st: RiP%: percentage of returns put into play against 1st serve
# RiP W%.1_x: percentage of points won when the return is put into play off 1st serve
# RetWnr%.1: percentage of return winners out of return points won on 1st serve
# 2nd: RiP%: percentage of returns put into play against 2nd serve
# RiP W%.2_x: percentage of points won when the return is put into play off 2nd serve
# RetWnr%.2: percentage of return winners out of return points won off 2nd serve
#
# RALLY
# RallyLen: average rally length
# Rlen-Serve: average rally length on serve points
# Rlen-Return: average rally length on return points
# 1-3 W%: percentage of rallies won lasting 1 to 3 shots
# 4-6 W%: percentage of rallies won lasting 4 to 6 shots
# 7-9 W%: percentage of rallies won lasting 7 to 9 shots
# 10+ W%: percentage of rallies won lasting more than 10 shots
# BH Slice%: percentage of backhand groundstrokes hit as slice from the baseline
# FHB: forehand power per match (higher is better)
# BHP: backhand power per match (higher is better)
#
# TACTICS
# SnV Freq: serve and volley attempts as a percentage of non-ace serves
# Net W%: percentage of points won at the net (after approaching forward)
# FH: Wnr%: percentage of forehands with topspin that ended the point, either by direct winner or by forcing an error
# BH: Wnr%: percentage of backhands that ended the point by winner
# Drop: Freq: drop shot frequency
# drop shot frequency from baseline
#
# KEY GAMES
# BP Games: return games with at least 1 break point
# BreakBack%: percentage of break backs in the game right after being broken
# BPF Games: service games where at least 1 break point was faced
# Consol%: hold percentage in the game following a break (consolidation)
# SvForSet: hold percentage when serving for the set
# SvStaySet: hold percentage when serving to stay in the set
# SvForMatch: hold percentage when serving for the match
# SvStayMatch: hold percentage when serving to stay in the match
#
# WINNERS AND UNFORCED ERRORS
# Wnr/Pt: percentage of points won with a winner
# UFE/Pt: percentage of points lost due to unforced errors
# FH Wnr/Pt: percentage of forehand winners per point
# BH Wnr/Pt: percentage of backhand winners per point
# vs Wnr/Pt: percentage of opponent winners per point
# vs UFE/Pt: percentage of opponent unforced errors per point

# %% [markdown]
# RESTO
# RiP%: %de restos puestos en juego
# Rip W%_x: %de puntos ganados cuando el resto se pone en juego
# RetWnr%: % de restos winner de %total de restos
# Slice%: slice/chip return del total % de todos los restos puestos en juego obligando a subir a la red a volear al rival
# 1st: RiP%: %de restos puestos en juego con 1er servicio
# RiP W%.1_x: %de puntos ganados cuando el resto se pone en juego tras el primer servicio
# RetWnr%.1: winner al resto del total % de los restos ganados con el primeros servicios
# 2nd: Rip%: % de los segundos servicios puestos en juego
# RiP W%.2_x: %de puntos ganados cuando el resto se pone en juego tras el segundo servicio
# RetWnr%.2: winner al resto as a % de los restos ganados con el segundos servicios
#
#
# RALLY
# RallyLen: media de duracion de rally
# Rlen-Serve:media de duracion de rally en los puntos al servicio
# Rlen-Return:media de duracion de rally en los puntos al resto
# 1-3 W%: porcentaje de rallys que gana si duran de 1 a 3 puntos
# 4-6 W%: porcentaje de rallys que gana si duran de 4 a 6 puntos
# 7-9 W%: porcentaje de rallys que gana si duran de 7 a 9 puntos
# 10+ W%: porcentaje de rallys que gana si duran mas de 10 puntos
# BH Slice%:slices por bh groundstroke (cortados de reves desde fondo de pista)
# FHB:forehand potencia por partido(higher is better)
# BHP:bh potencia por partido(higher is better)
#
# SERVICIO
# Unret%: % de servicio que fueron unreturned
# <=3 W%: % puntos al servicio ganados en menos de 3 toques
# RiP W%_y: % de puntos ganados cuando el resto fue puesto en juego
# SvImpact: estadistica avanzada que calcula cuantos puntos al servicio han sido ganado gracias al saque
# 1st: Unret%: % de los primeros servicios que no se han devuelto
# <=3 W%: % puntos al primer servicio ganados en menos de 3 toques
# RiP W%: % de puntos ganados cuando el resto fue puesto en juego con el primer servicio
# D Wide%: % de primeros saques desde el lado deuce que fueron dirigidos al lado abierto (wide).
# A Wide%: % de primeros saques desde el lado ad que fueron dirigidos al lado abierto (wide). MIRANDO ESTAS TIENE UQE HACER PREDICCION DE PUNTOS CLAVE COMAPRANDO CON LOS PERFILES
# 2nd: Unret%: % de segundo servicio que fueron unreturned
# <=3 W%.2: % puntos al segundo servicio ganados en menos de 3 toques
# RiP W%.2_y: % de puntos ganados cuando el resto fue puesto en juego con el segundo servicio
# 2ndAgg:  agresion score de 2o servicio(0 is average, higher= more aggresive)  ESTA ES IMPORTANTE PARA CONCLUSIONES
#
# TACTICA
# SnV Freq: serve and volley attempts del % de saques que no son aces
# ver si meto la siguiente, creo que deberia, es tarde ya, nombro solo cuidado pq es un jugador que hace muchas voleas y ya
# Net W%: puntos ganados en la red (cuando se adelanta en pista y se acerca a la red)
# FH: Wnr%: Porcentaje de golpes de derecha con topspin que terminaron el punto, ya sea por un winner directo o porque forzaron un error del rival.
# BH: Wnr%: winner por backhand (de reves)
# Drop: Freq: frecuencia con la que realiza dejadas IMPORTNATE
# dejadas freq desde fondo de pista
#
#
# KEY GAME
# BP Games: return games con al menos 1 bp
# BreakBack%:  % de break en juegos inmediatamente despues de haber perdido el saque IMPORTANTE
# BPF Games: juegos al servicio con al menos 1 bp concedido
# Consol%:hold % en juegos despues de conseguir un break (ganar el juego anterior del servicio del rival)
# SvForSet:hold rate cuando sacas para ganar el set
# SvStaySet:hold rate cuando sacas para no perder el set
# SvForMatch:hold rate cuando sacas para ganar el partido
# SvStayMatch:hold rate cuando sacas para no perder el partido
#
#
#
# Winner
#
# Wnr/Pt: %winner por punto
# UFE/Pt:%error no forzado por punto
# FH Wnr/Pt: winner de derecha por punto
# BH Wnr/Pt: winner reves por punto
# vs Wnr/Pt: winner del rival por punto
# vs UFE/Pt: unforces del rival por punto

# %% [markdown]
# RESTO
# RiP%: %de restos puestos en juego
# Rip W%_x: %de puntos ganados cuando el resto se pone en juego
# RetWnr%: % de restos winner de %total de restos
# RDI: no usar
# Slice%: slice/chip return del total % de todos los restos puestos en juego obligando a subir a la red a volear al rival
# 1st: RiP%: %de restos puestos en juego con 1er servicio
# RiP W%.1_x: %de puntos ganados cuando el resto se pone en juego tras el primer servicio
# RetWnr%.1: winner al resto del total % de los restos ganados con el primeros servicios
# RDI.1:no usar
# Slice%.1: no usar
# 2nd: Rip%: % de los segundos servicios puestos en juego
# RiP W%.2_x: %de puntos ganados cuando el resto se pone en juego tras el segundo servicio
# RetWnr%.2: winner al resto as a % de los restos ganados con el segundos servicios
# RDI.2: no usar
# Slice%.2: no usar
#
#
# RALLY
# RallyLen: media de duracion de rally
# Rlen-Serve:media de duracion de rally en los puntos al servicio
# Rlen-Return:media de duracion de rally en los puntos al resto
# 1-3 W%: porcentaje de rallys que gana si duran de 1 a 3 puntos
# 4-6 W%: porcentaje de rallys que gana si duran de 4 a 6 puntos
# 7-9 W%: porcentaje de rallys que gana si duran de 7 a 9 puntos
# 10+ W%: porcentaje de rallys que gana si duran mas de 10 puntos
# FH/GS: no usar
# BH Slice%:slices por bh groundstroke (cortados de reves desde fondo de pista)
# FHB:forehand potencia por partido(higher is better)
# FHP/100:no usar
# BHP:bh potencia por partido(higher is better)
# BHP/100:no usar
#
# SERVICIO
# Unret%: % de servicio que fueron unreturned
# <=3 W%: % puntos al servicio ganados en menos de 3 toques
# RiP W%_y: % de puntos ganados cuando el resto fue puesto en juego
# SvImpact: estadistica avanzada que calcula cuantos puntos al servicio han sido ganado gracias al saque
# 1st: Unret%: % de los primeros servicios que no se han devuelto
# <=3 W%: % puntos al primer servicio ganados en menos de 3 toques
# RiP W%: % de puntos ganados cuando el resto fue puesto en juego con el primer servicio
# SvImpact.1: no usar
# D Wide%: % de primeros saques desde el lado deuce que fueron dirigidos al lado abierto (wide).
# A Wide%: % de primeros saques desde el lado ad que fueron dirigidos al lado abierto (wide). MIRANDO ESTAS TIENE UQE HACER PREDICCION DE PUNTOS CLAVE COMAPRANDO CON LOS PERFILES
# BP Wide%: no usar
# 2nd: Unret%: % de segundo servicio que fueron unreturned
# <=3 W%.2: % puntos al segundo servicio ganados en menos de 3 toques
# RiP W%.2_y: % de puntos ganados cuando el resto fue puesto en juego con el segundo servicio
# 2ndAgg:  agresion score de 2o servicio(0 is average, higher= more aggresive)  ESTA ES IMPORTANTE PARA CONCLUSIONES
#
# TACTICA
# SnV Freq: serve and volley attempts del % de saques que no son aces
# ver si meto la siguiente, creo que deberia, es tarde ya, nombro solo cuidado pq es un jugador que hace muchas voleas y ya
# Net Freq:no usar
# Net W%: puntos ganados en la red (cuando se adelanta en pista y se acerca a la red)
# FH: Wnr%: Porcentaje de golpes de derecha con topspin que terminaron el punto, ya sea por un winner directo o porque forzaron un error del rival.
# DTL Wnr%: no usar
# IO Wnr%: no usar
# BH: Wnr%: winner por backhand (de reves)
# DTL Wnr%: no usar
# Drop: Freq: frecuencia con la que realiza dejadas IMPORTNATE
# dejadas freq desde fondo de pista
# RallyAgg: no usar
# ReturnAgg:no usar
#
# KEY GAME
# BP Games: return games con al menos 1 bp
# BP Conv/BPG: no usar
# BreakBack%:  % de break en juegos inmediatamente despues de haber perdido el saque IMPORTANTE
# BPF Games: juegos al servicio con al menos 1 bp concedido
# Hold/BPFG: no usae
# Consol%:hold % en juegos despues de conseguir un break (ganar el juego anterior del servicio del rival)
# SvForSet:hold rate cuando sacas para ganar el set
# SvStaySet:hold rate cuando sacas para no perder el set
# SvForMatch:hold rate cuando sacas para ganar el partido
# SvStayMatch:hold rate cuando sacas para no perder el partido
#
# KEY POINTS NO USAR NINGUNO
# GP Conv: bp converted
# SP Conv:set point conv
# MP Conv: match point conv
# BP Saved: bp sav
# SP Saved:
# MP Saved:
# TB SPW: tb serve point won
# TB RPW:tb return point won
#
# PBP STATS NO USAR NINGUNO
# BLR:ratio de puntos importantes ganados respecto a los perdidos, mas de 1 si, menos de 1 no
# DR+
# EI: average leverage rating of all points
# CBF:
# Deuce A%:Ace rate on deuce-court point
# Deuce SPW%:ratio de puntos ganados al servicio en deuce court
# % de puntos ganados al servicio desde el lado deuce
# Ad A%:ace rate on ad-court point
# Ad SPW%:ratio de service point won in the ad court
#
# Winner
# Winners: no usar
# UFEs: no usar
# Ratio:no usar
# Wnr/Pt: %winner por punto
# UFE/Pt:%error no forzado por punto
# RallyRatio: no usar
# Rally Wnr/Pt: no usar
# Rally UFE/Pt: no usar
# FH Wnr/Pt: winner de derecha por punto
# BH Wnr/Pt: winner reves por punto
# vs Wnr/Pt: winner del rival por punto
# vs UFE/Pt: unforces del rival por punto
